# %%
# Importing requiered libraries
import numpy as np
import pandas as pd
import importlib
import utils.validation

# Reload the functions module
importlib.reload(utils.validation)
# Out:
# <module 'utils.validation' from 's:\\Courses\\Data Science\\0. Henry\\M7 - Labs - Project MLOps\\recommendation-system-movies-similarity-and-rating\\data\\utils\\validation.py'>

# %% [markdown]
# # Data Transformation Process

# %% [markdown]
# #### Importing files

# %%
# Importing movies_dataset.csv file
dataset_path_1 = "raw data\movies_dataset.csv"
dataset_path_2 = "raw data\credits.csv"

# Setting low_memory=False - To read the entire file so it determines the data types accurately. 
# Note: It can increase memory usage for larger datasets
info_movies = pd.read_csv(dataset_path_1, low_memory=False)
info_credits = pd.read_csv(dataset_path_2, low_memory=False)

# %% [markdown]
# #### Merge files in one dataset

# %%
# Checking number of rows for each file
print("rows in movies:", info_movies.shape[0])
print("rows in credits:", info_credits.shape[0])
# Out:
# rows in movies: 45466
# rows in credits: 45476

# %%
# Checking for duplicates in id movies
duplicates_movies = utils.validation.count_duplicates(info_movies['id'])
print("Duplicated id values in movies", duplicates_movies)
# Out:
# Duplicated id values in movies id
# 141971    2
# 105045    1
# 11115     1
# 12600     1
# 10991     1
# 97995     1
# 298721    1
# 99080     1
# 159849    1
# 4912      1
# 15028     1
# 132641    1
# 42495     1
# 168538    1
# 69234     1
# 110428    1
# 5511      1
# 25541     1
# 18440     1
# 152795    1
# 119916    1
# 84198     1
# 109962    1
# 77221     1
# 13209     1
# 22649     1
# 14788     1
# 23305     1
# 265189    1
# Name: count, dtype: int64

# %%
# Removing duplicates in id movies
info_movies_2 = utils.validation.remove_duplicates(info_movies, 'id')

# %%
# Checking for duplicates in id credits
duplicates_credits = utils.validation.count_duplicates(info_credits["id"])
print("Duplicated id values in movies", duplicates_credits)
# Out:
# Duplicated id values in movies id
# 141971    2
# 105045    1
# 42495     1
# 157301    1
# 9755      1
# 123634    1
# 8767      1
# 43629     1
# 187156    1
# 69234     1
# 168538    1
# 132641    1
# 11752     1
# 15028     1
# 4912      1
# 159849    1
# 99080     1
# 298721    1
# 97995     1
# 10991     1
# 12600     1
# 142563    1
# 24026     1
# 5511      1
# 24023     1
# 23305     1
# 14788     1
# 22649     1
# 13209     1
# 77221     1
# 109962    1
# 84198     1
# 119916    1
# 152795    1
# 18440     1
# 25541     1
# 110428    1
# 11115     1
# 116723    1
# 3057      1
# 125458    1
# 199591    1
# 265189    1
# Name: count, dtype: int64

# %%
# Removing duplicates in id credits
info_credits_2 = utils.validation.remove_duplicates(info_credits, 'id')

# %%
# Checking data type of the values and the amount of each
value_counts_movies = info_movies_2["id"].value_counts()
print("id movies:", value_counts_movies.index.to_series().apply(type).value_counts())

value_counts_credits = info_credits_2["id"].value_counts()
print("id credits:", value_counts_credits.index.to_series().apply(type).value_counts())
# Out:
# id movies: id
# <class 'str'>    45436
# Name: count, dtype: int64
# id credits: id
# <class 'int'>    45432
# Name: count, dtype: int64

# %%
# Checking for null values
null_count_movies = info_movies_2["id"].isnull().sum()
print("Null values in movies:", null_count_movies)

null_count_credits = info_credits_2["id"].isnull().sum()
print("Null values in credits:", null_count_credits)
# Out:
# Null values in movies: 0
# Null values in credits: 0

# %%
# Checking for blank values
blank_count_movies = utils.validation.count_blanks(info_movies_2, "id")
print("Null values in movies:", blank_count_movies)

blank_count_credits = utils.validation.count_blanks(info_credits_2, "id")
print("Null values in credits:", blank_count_credits)
# Out:
# Null values in movies: 0
# Null values in credits: 0

# %% [markdown]
# ##### Working with id values from movies dataset

# %%
# Some str values are date time pattern
# Using data_pattern function created and stored in validation
id_invalid_values = utils.validation.date_pattern(info_movies_2["id"], 0)
id_invalid_values
# Out:
# ['1997-08-20', '2012-09-29', '2014-01-01']

# %%
# Deleting str values 
# These values are removed because they are not sensitive data that affect the creation of the movie recommendation system.
info_movies_2 = info_movies_2[~info_movies_2["id"].isin(id_invalid_values)]

# %%
# Transforming values to numeric type using convert_to_numeric function created and stored in validation
info_movies_2 = utils.validation.convert_to_numeric(info_movies_2, "id")

# %%
# Checking data type of the values and the amount of each
value_counts_movies_2 = info_movies_2["id"].value_counts()
print("id movies:", value_counts_movies_2.index.to_series().apply(type).value_counts())
# Out:
# id movies: id
# <class 'int'>    45433
# Name: count, dtype: int64

# %% [markdown]
# ##### Working with id values of credits

# %%
# Checking the amount of unique values
unique_values_credits = info_credits_2["id"].unique()

print("Number of rows:", info_credits_2["id"].shape[0])
print("Number of unique values:",unique_values_credits.shape[0])
# Out:
# Number of rows: 45432
# Number of unique values: 45432

# %%
# These ids don't need any change

# %% [markdown]
# ##### Merging files

# %%
# Merge the datasets based on the common "id" column
data_movies = pd.merge(info_movies_2, info_credits_2, on="id", how="left")

# %%
utils.validation.count_duplicates(data_movies["id"])
# Out:
# Series([], Name: count, dtype: int64)

# %% [markdown]
# #### Delete unimportant columns

# %%
# Deleting columns (video,imdb_id,adult,original_title,poster_path y homepage)
columns_to_drop = ["video", "imdb_id", "adult", "original_title", "poster_path", "homepage"]
data_movies_1 = data_movies.drop(columns=columns_to_drop)

# %% [markdown]
# #### Replace null values in "revenue" and "budget"

# %%
# Replacing null values with 0 in "revenue" and "budget"
# Later on will be created an inversion return column, thats why these values can't be null
columns_to_replace = ["revenue", "budget"]
data_movies_1[columns_to_replace] = data_movies_1[columns_to_replace].fillna(0)

# %% [markdown]
# #### Standardize "release date" values

# %%
# Check the number of rows that will be eliminated, to see if the process may affect considerably
null_count = data_movies_1["release_date"].isnull().sum()
print("Number of null values in 'release_date':", null_count)
print("Number of rows in table:", data_movies_1.shape[0])
# Out:
# Number of null values in 'release_date': 87
# Number of rows in table: 45433

# %%
# Deleting rows with null values in release_date
data_movies_2 = data_movies_1.dropna(subset=["release_date"])

# %%
# Checking the date time type of the values from the release date column
# To verify if values are standardized or not ("object" will mean they're not)
data_type = data_movies_2["release_date"].dtype
print("Data type of 'release_date' column:", data_type)
# Out:
# Data type of 'release_date' column: object

# %% [markdown]
# Standardizing "realease_date" to date format (YYYY-mm-dd)

# %%
# Checking the amount of values that have unique values
unique_values = data_movies_2["release_date"].unique()

print("Number of rows:", data_movies_2["release_date"].shape[0])
print("Number of unique values:",unique_values.shape[0])
# Out:
# Number of rows: 45346
# Number of unique values: 17333

# %%
# Checking data type of unique values and the amount of each
value_counts = data_movies_2["release_date"].value_counts()

print(value_counts.index.to_series().apply(type).value_counts())
# Out:
# release_date
# <class 'str'>    17333
# Name: count, dtype: int64

# %%
# Having only "str" type on unique values
# Identify values that do not have the format "yyyy-mm-dd", using the function date_pattern created and stored in validation 
values_without_pattern = utils.validation.date_pattern(data_movies_2["release_date"], 1)
values_without_pattern
# Out:
# []

# %%
# All values have "yyyy-mm-dd" patter, transforming all values to datetime type

data_movies_3 = data_movies_2.copy()

# Convert "release_date" column to datetime
data_movies_3["release_date"] = pd.to_datetime(data_movies_3["release_date"])

# %%
# Checking data type of release_date
date_type = data_movies_3["release_date"].dtype
print("dates", date_type)
# Out:
# dates datetime64[ns]

# %% [markdown]
# #### Create "release_year" with year value from "release_date"

# %%
# Creating the column "release_year" using the year from "release_date"
data_movies_3["release_year"] = data_movies_3["release_date"].dt.year

# %%
# Checking data type of release_year
year_type = data_movies_3["release_year"].dtype
print("year", year_type)
# Out:
# year int32

# %% [markdown]
# #### Create "return" column

# %%
# Checking the type of the values from "revenue" and "budget"
print("revenue type:", data_movies_3["revenue"].dtype)
print("budget type:", data_movies_3["budget"].dtype)
# Out:
# revenue type: float64
# budget type: object

# %% [markdown]
# ##### Transforming budget values

# %%
# Checking the type of values from "budget", and how many of them are in the column
budget_data_types = data_movies_3["budget"].apply(type).value_counts()

print(budget_data_types)
print("Total of rows:", data_movies_3["budget"].shape[0])
# Out:
# budget
# <class 'str'>    45346
# Name: count, dtype: int64
# Total of rows: 45346

# %%
# Transforming "budget" values to numeric type, using convert_to_numeric funtion created and stored in validation
data_movies_4 = utils.validation.convert_to_numeric(data_movies_3, "budget")

# %%
# Checking "budget" values are numeric type
print("budget type:", data_movies_4["budget"].dtype)
# Out:
# budget type: int64

# %% [markdown]
# ##### Creating return column

# %%
# Creating the "return" column ("revenue" / "budget")
data_movies_4["return"] = data_movies_4["revenue"] / data_movies_4["budget"]
data_movies_4.loc[(data_movies_4["revenue"] == 0) | (data_movies_4["budget"] == 0), "return"] = 0

# %% [markdown]
# #### Unnest data from columns

# %% [markdown]
# ##### Working with "crew" values

# %% [markdown]
# Analyzing values

# %%
# Total number of values
data_movies_4["crew"].shape[0]
# Out:
# 45346

# %%
# Checking amount of data type
value_counts_crew = data_movies_4["crew"].value_counts()
print("id movies:", value_counts_crew.index.to_series().apply(type).value_counts())
# Out:
# id movies: crew
# <class 'str'>    44623
# Name: count, dtype: int64

# %%
# Total number of blank values
blanks_crew = utils.validation.count_blanks(data_movies_4, "crew")
print(blanks_crew)
# Out:
# 1

# %%
# Total number of duplicates
duplicates_crew = utils.validation.count_duplicates(data_movies_4["crew"])
print(duplicates_crew)
# Out:
# crew
# []    722
# Name: count, dtype: int64

# %%
# After checking the data types
# Replace "[]" with Empty space
data_movies_5 = data_movies_4.copy()
data_movies_5["crew"] = data_movies_5["crew"].replace("[]", "")

# %%
utils.validation.replace_nan_with_empty_string(data_movies_5, "crew")
# Out:
#                                    belongs_to_collection    budget
# 0      {'id': 10194, 'name': 'Toy Story Collection', ...  30000000  \
# 1                                                    NaN  65000000
# 2      {'id': 119050, 'name': 'Grumpy Old Men Collect...         0
# 3                                                    NaN  16000000
# 4      {'id': 96871, 'name': 'Father of the Bride Col...         0
# ...                                                  ...       ...
# 45427                                                NaN         0
# 45429                                                NaN         0
# 45430                                                NaN         0
# 45431                                                NaN         0
# 45432                                                NaN         0
#
#                                                   genres      id
# 0      [{'id': 16, 'name': 'Animation'}, {'id': 35, '...     862  \
# 1      [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...    8844
# 2      [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...   15602
# 3      [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...   31357
# 4                         [{'id': 35, 'name': 'Comedy'}]   11862
# ...                                                  ...     ...
# 45427  [{'id': 18, 'name': 'Drama'}, {'id': 28, 'name...   30840
# 45429                      [{'id': 18, 'name': 'Drama'}]  111109
# 45430  [{'id': 28, 'name': 'Action'}, {'id': 18, 'nam...   67758
# 45431                                                 []  227506
# 45432                                                 []  461257
#
#       original_language                                           overview
# 0                    en  Led by Woody, Andy's toys live happily in his ...  \
# 1                    en  When siblings Judy and Peter discover an encha...
# 2                    en  A family wedding reignites the ancient feud be...
# 3                    en  Cheated on, mistreated and stepped on, the wom...
# 4                    en  Just when George Banks has recovered from his ...
# ...                 ...                                                ...
# 45427                en  Yet another version of the classic epic, with ...
# 45429                tl  An artist struggles to finish his work while a...
# 45430                en  When one of her hits goes wrong, a professiona...
# 45431                en  In a small town live two brothers, one a minis...
# 45432                en  50 years after decriminalisation of homosexual...
#
#       popularity                               production_companies
# 0      21.946943     [{'name': 'Pixar Animation Studios', 'id': 3}]  \
# 1      17.015539  [{'name': 'TriStar Pictures', 'id': 559}, {'na...
# 2        11.7129  [{'name': 'Warner Bros.', 'id': 6194}, {'name'...
# 3       3.859495  [{'name': 'Twentieth Century Fox Film Corporat...
# 4       8.387519  [{'name': 'Sandollar Productions', 'id': 5842}...
# ...          ...                                                ...
# 45427   5.683753  [{'name': 'Westdeutscher Rundfunk (WDR)', 'id'...
# 45429   0.178241             [{'name': 'Sine Olivia', 'id': 19653}]
# 45430   0.903007  [{'name': 'American World Pictures', 'id': 6165}]
# 45431   0.003503               [{'name': 'Yermoliev', 'id': 88753}]
# 45432   0.163015                                                 []
#
#                                     production_countries release_date  ...
# 0      [{'iso_3166_1': 'US', 'name': 'United States o...   1995-10-30  ...  \
# 1      [{'iso_3166_1': 'US', 'name': 'United States o...   1995-12-15  ...
# 2      [{'iso_3166_1': 'US', 'name': 'United States o...   1995-12-22  ...
# 3      [{'iso_3166_1': 'US', 'name': 'United States o...   1995-12-22  ...
# 4      [{'iso_3166_1': 'US', 'name': 'United States o...   1995-02-10  ...
# ...                                                  ...          ...  ...
# 45427  [{'iso_3166_1': 'CA', 'name': 'Canada'}, {'iso...   1991-05-13  ...
# 45429      [{'iso_3166_1': 'PH', 'name': 'Philippines'}]   2011-11-17  ...
# 45430  [{'iso_3166_1': 'US', 'name': 'United States o...   2003-08-01  ...
# 45431           [{'iso_3166_1': 'RU', 'name': 'Russia'}]   1917-10-21  ...
# 45432   [{'iso_3166_1': 'GB', 'name': 'United Kingdom'}]   2017-06-09  ...
#
#                                         spoken_languages    status
# 0               [{'iso_639_1': 'en', 'name': 'English'}]  Released  \
# 1      [{'iso_639_1': 'en', 'name': 'English'}, {'iso...  Released
# 2               [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 3               [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 4               [{'iso_639_1': 'en', 'name': 'English'}]  Released
# ...                                                  ...       ...
# 45427           [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 45429                  [{'iso_639_1': 'tl', 'name': ''}]  Released
# 45430           [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 45431                                                 []  Released
# 45432           [{'iso_639_1': 'en', 'name': 'English'}]  Released
#
#                                                  tagline
# 0                                                    NaN  \
# 1              Roll the dice and unleash the excitement!
# 2      Still Yelling. Still Fighting. Still Ready for...
# 3      Friends are the people who let you be yourself...
# 4      Just When His World Is Back To Normal... He's ...
# ...                                                  ...
# 45427                                                NaN
# 45429                                                NaN
# 45430                             A deadly game of wits.
# 45431                                                NaN
# 45432                                                NaN
#
#                              title vote_average vote_count
# 0                        Toy Story          7.7     5415.0  \
# 1                          Jumanji          6.9     2413.0
# 2                 Grumpier Old Men          6.5       92.0
# 3                Waiting to Exhale          6.1       34.0
# 4      Father of the Bride Part II          5.7      173.0
# ...                            ...          ...        ...
# 45427                   Robin Hood          5.7       26.0
# 45429          Century of Birthing          9.0        3.0
# 45430                     Betrayal          3.8        6.0
# 45431             Satan Triumphant          0.0        0.0
# 45432                     Queerama          0.0        0.0
#
#                                                     cast
# 0      [{'cast_id': 14, 'character': 'Woody (voice)',...  \
# 1      [{'cast_id': 1, 'character': 'Alan Parrish', '...
# 2      [{'cast_id': 2, 'character': 'Max Goldman', 'c...
# 3      [{'cast_id': 1, 'character': "Savannah 'Vannah...
# 4      [{'cast_id': 1, 'character': 'George Banks', '...
# ...                                                  ...
# 45427  [{'cast_id': 1, 'character': 'Sir Robert Hode'...
# 45429  [{'cast_id': 1002, 'character': 'Sister Angela...
# 45430  [{'cast_id': 6, 'character': 'Emily Shaw', 'cr...
# 45431  [{'cast_id': 2, 'character': '', 'credit_id': ...
# 45432                                                 []
#
#                                                     crew release_year
# 0      [{'credit_id': '52fe4284c3a36847f8024f49', 'de...         1995  \
# 1      [{'credit_id': '52fe44bfc3a36847f80a7cd1', 'de...         1995
# 2      [{'credit_id': '52fe466a9251416c75077a89', 'de...         1995
# 3      [{'credit_id': '52fe44779251416c91011acb', 'de...         1995
# 4      [{'credit_id': '52fe44959251416c75039ed7', 'de...         1995
# ...                                                  ...          ...
# 45427  [{'credit_id': '52fe44439251416c9100a899', 'de...         1991
# 45429  [{'credit_id': '52fe4af1c3a36847f81e9b15', 'de...         2011
# 45430  [{'credit_id': '52fe4776c3a368484e0c8387', 'de...         2003
# 45431  [{'credit_id': '533bccebc3a36844cf0011a7', 'de...         1917
# 45432  [{'credit_id': '593e676c92514105b702e68e', 'de...         2017
#
#           return
# 0      12.451801
# 1       4.043035
# 2       0.000000
# 3       5.090760
# 4       0.000000
# ...          ...
# 45427   0.000000
# 45429   0.000000
# 45430   0.000000
# 45431   0.000000
# 45432   0.000000
#
# [45346 rows x 22 columns]

# %%
# Total number of blank values
utils.validation.get_column_summary(data_movies_5, "crew")
# Out:
# (crew
#  <class 'str'>    45346
#  Name: count, dtype: int64,
#  'total values:',
#  45346)

# %% [markdown]
# Checking valid python syntax

# %%
# Check valid python syntax for crew column
valid_crew = utils.validation.check_valid_expression(data_movies_5, "crew")
valid_crew
# Out:
# {'valid_count': 44622,
#  'invalid_count': 724,
#  'nan_count': 0,
#  'blank_count': 724,
#  'error_count': 0,
#  'invalid_values': [],
#  'error_values': []}

# %% [markdown]
# Extracting values

# %%
data_movies_6 = data_movies_5.copy()

# Ectracting nested values from crew
column_name = "crew"
keys = ["id", "name", "gender", "department", 'job']
new_columns = ["crew_id", "crew_name", "crew_gender", "crew_department", "crew_job"]

# %%
utils.validation.extract_values(data_movies_6, column_name, keys, new_columns)
# Out:
#                                    belongs_to_collection    budget
# 0      {'id': 10194, 'name': 'Toy Story Collection', ...  30000000  \
# 1                                                    NaN  65000000
# 2      {'id': 119050, 'name': 'Grumpy Old Men Collect...         0
# 3                                                    NaN  16000000
# 4      {'id': 96871, 'name': 'Father of the Bride Col...         0
# ...                                                  ...       ...
# 45427                                                NaN         0
# 45429                                                NaN         0
# 45430                                                NaN         0
# 45431                                                NaN         0
# 45432                                                NaN         0
#
#                                                   genres      id
# 0      [{'id': 16, 'name': 'Animation'}, {'id': 35, '...     862  \
# 1      [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...    8844
# 2      [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...   15602
# 3      [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...   31357
# 4                         [{'id': 35, 'name': 'Comedy'}]   11862
# ...                                                  ...     ...
# 45427  [{'id': 18, 'name': 'Drama'}, {'id': 28, 'name...   30840
# 45429                      [{'id': 18, 'name': 'Drama'}]  111109
# 45430  [{'id': 28, 'name': 'Action'}, {'id': 18, 'nam...   67758
# 45431                                                 []  227506
# 45432                                                 []  461257
#
#       original_language                                           overview
# 0                    en  Led by Woody, Andy's toys live happily in his ...  \
# 1                    en  When siblings Judy and Peter discover an encha...
# 2                    en  A family wedding reignites the ancient feud be...
# 3                    en  Cheated on, mistreated and stepped on, the wom...
# 4                    en  Just when George Banks has recovered from his ...
# ...                 ...                                                ...
# 45427                en  Yet another version of the classic epic, with ...
# 45429                tl  An artist struggles to finish his work while a...
# 45430                en  When one of her hits goes wrong, a professiona...
# 45431                en  In a small town live two brothers, one a minis...
# 45432                en  50 years after decriminalisation of homosexual...
#
#       popularity                               production_companies
# 0      21.946943     [{'name': 'Pixar Animation Studios', 'id': 3}]  \
# 1      17.015539  [{'name': 'TriStar Pictures', 'id': 559}, {'na...
# 2        11.7129  [{'name': 'Warner Bros.', 'id': 6194}, {'name'...
# 3       3.859495  [{'name': 'Twentieth Century Fox Film Corporat...
# 4       8.387519  [{'name': 'Sandollar Productions', 'id': 5842}...
# ...          ...                                                ...
# 45427   5.683753  [{'name': 'Westdeutscher Rundfunk (WDR)', 'id'...
# 45429   0.178241             [{'name': 'Sine Olivia', 'id': 19653}]
# 45430   0.903007  [{'name': 'American World Pictures', 'id': 6165}]
# 45431   0.003503               [{'name': 'Yermoliev', 'id': 88753}]
# 45432   0.163015                                                 []
#
#                                     production_countries release_date  ...
# 0      [{'iso_3166_1': 'US', 'name': 'United States o...   1995-10-30  ...  \
# 1      [{'iso_3166_1': 'US', 'name': 'United States o...   1995-12-15  ...
# 2      [{'iso_3166_1': 'US', 'name': 'United States o...   1995-12-22  ...
# 3      [{'iso_3166_1': 'US', 'name': 'United States o...   1995-12-22  ...
# 4      [{'iso_3166_1': 'US', 'name': 'United States o...   1995-02-10  ...
# ...                                                  ...          ...  ...
# 45427  [{'iso_3166_1': 'CA', 'name': 'Canada'}, {'iso...   1991-05-13  ...
# 45429      [{'iso_3166_1': 'PH', 'name': 'Philippines'}]   2011-11-17  ...
# 45430  [{'iso_3166_1': 'US', 'name': 'United States o...   2003-08-01  ...
# 45431           [{'iso_3166_1': 'RU', 'name': 'Russia'}]   1917-10-21  ...
# 45432   [{'iso_3166_1': 'GB', 'name': 'United Kingdom'}]   2017-06-09  ...
#
#        vote_count                                               cast
# 0          5415.0  [{'cast_id': 14, 'character': 'Woody (voice)',...  \
# 1          2413.0  [{'cast_id': 1, 'character': 'Alan Parrish', '...
# 2            92.0  [{'cast_id': 2, 'character': 'Max Goldman', 'c...
# 3            34.0  [{'cast_id': 1, 'character': "Savannah 'Vannah...
# 4           173.0  [{'cast_id': 1, 'character': 'George Banks', '...
# ...           ...                                                ...
# 45427        26.0  [{'cast_id': 1, 'character': 'Sir Robert Hode'...
# 45429         3.0  [{'cast_id': 1002, 'character': 'Sister Angela...
# 45430         6.0  [{'cast_id': 6, 'character': 'Emily Shaw', 'cr...
# 45431         0.0  [{'cast_id': 2, 'character': '', 'credit_id': ...
# 45432         0.0                                                 []
#
#                                                     crew release_year
# 0      [{'credit_id': '52fe4284c3a36847f8024f49', 'de...         1995  \
# 1      [{'credit_id': '52fe44bfc3a36847f80a7cd1', 'de...         1995
# 2      [{'credit_id': '52fe466a9251416c75077a89', 'de...         1995
# 3      [{'credit_id': '52fe44779251416c91011acb', 'de...         1995
# 4      [{'credit_id': '52fe44959251416c75039ed7', 'de...         1995
# ...                                                  ...          ...
# 45427  [{'credit_id': '52fe44439251416c9100a899', 'de...         1991
# 45429  [{'credit_id': '52fe4af1c3a36847f81e9b15', 'de...         2011
# 45430  [{'credit_id': '52fe4776c3a368484e0c8387', 'de...         2003
# 45431  [{'credit_id': '533bccebc3a36844cf0011a7', 'de...         1917
# 45432  [{'credit_id': '593e676c92514105b702e68e', 'de...         2017
#
#           return                                            crew_id
# 0      12.451801  [7879, 12891, 7, 12892, 12893, 12894, 12895, 1...  \
# 1       4.043035  [511, 876, 1729, 4945, 4951, 4952, 8023, 9967,...
# 2       0.000000                     [26502, 16837, 16837, 1551320]
# 3       5.090760  [2178, 5144, 5144, 21968, 70592, 111118, 11111...
# 4       0.000000      [37, 5506, 17698, 17698, 26160, 56106, 68755]
# ...          ...                                                ...
# 45427   0.000000  [17784, 1471628, 39812, 1471628, 18073, 10716,...
# 45429   0.000000  [1051381, 1051381, 1728582, 1051381, 1051381, ...
# 45430   0.000000              [67753, 19713, 549355, 549356, 58818]
# 45431   0.000000                                 [1085341, 1195656]
# 45432   0.000000                                          [1344495]
#
#                                                crew_name
# 0      [John Lasseter, Joss Whedon, Andrew Stanton, J...  \
# 1      [Larry J. Franco, Jonathan Hensleigh, James Ho...
# 2      [Howard Deutch, Mark Steven Johnson, Mark Stev...
# 3      [Forest Whitaker, Ronald Bass, Ronald Bass, Ez...
# 4      [Alan Silvestri, Elliot Davis, Nancy Meyers, N...
# ...                                                  ...
# 45427  [John Irvin, Sam Resnick, John McGrath, Sam Re...
# 45429  [Lav Diaz, Lav Diaz, Dante Perez, Lav Diaz, La...
# 45430  [Mark L. Lester, C. Courtney Joyner, Jeffrey G...
# 45431            [Yakov Protazanov, Joseph N. Ermolieff]
# 45432                                    [Daisy Asquith]
#
#                                              crew_gender
# 0      [2, 2, 2, 2, 0, 1, 0, 2, 2, 2, 2, 2, 0, 0, 0, ...  \
# 1       [2, 2, 2, 2, 2, 0, 0, 2, 2, 2, 2, 2, 2, 2, 2, 2]
# 2                                           [2, 2, 2, 2]
# 3                         [2, 0, 0, 2, 1, 0, 0, 0, 2, 0]
# 4                                  [2, 2, 1, 1, 2, 2, 2]
# ...                                                  ...
# 45427                        [2, 0, 2, 0, 1, 0, 0, 2, 1]
# 45429                                 [0, 0, 0, 0, 0, 0]
# 45430                                    [2, 2, 2, 0, 2]
# 45431                                             [0, 2]
# 45432                                                [0]
#
#                                          crew_department
# 0      [Directing, Writing, Writing, Writing, Writing...  \
# 1      [Production, Writing, Sound, Directing, Editin...
# 2                    [Directing, Writing, Writing, Crew]
# 3      [Directing, Writing, Production, Production, P...
# 4      [Sound, Camera, Writing, Production, Writing, ...
# ...                                                  ...
# 45427  [Directing, Writing, Writing, Writing, Product...
# 45429    [Directing, Writing, Art, Sound, Editing, Crew]
# 45430       [Directing, Writing, Writing, Sound, Camera]
# 45431                            [Directing, Production]
# 45432                                        [Directing]
#
#                                                 crew_job
# 0      [Director, Screenplay, Screenplay, Screenplay,...
# 1      [Executive Producer, Screenplay, Original Musi...
# 2        [Director, Characters, Writer, Sound Recordist]
# 3      [Director, Screenplay, Producer, Producer, Pro...
# 4      [Original Music Composer, Director of Photogra...
# ...                                                  ...
# 45427  [Director, Writer, Writer, Story, Producer, Mu...
# 45429  [Director, Writer, Production Design, Music, E...
# 45430  [Director, Screenplay, Screenplay, Original Mu...
# 45431                               [Director, Producer]
# 45432                                         [Director]
#
# [45346 rows x 27 columns]

# %% [markdown]
# ##### Working with "cast" values

# %% [markdown]
# Analyzing values

# %%
# Total number of values
data_movies_6["cast"].shape[0]
# Out:
# 45346

# %%
# Checking amount of data type
value_counts_cast = data_movies_6["cast"].value_counts()
print("id movies:", value_counts_cast.index.to_series().apply(type).value_counts())
# Out:
# id movies: cast
# <class 'str'>    42998
# Name: count, dtype: int64

# %%
# Total number of blank values
blanks_cast = utils.validation.count_blanks(data_movies_6, "cast")
print(blanks_cast)
# Out:
# 1

# %%
# Total number of duplicates
duplicates_cast = utils.validation.count_duplicates(data_movies_6["cast"])
print(duplicates_cast)
# Out:
# cast
# []    2347
# Name: count, dtype: int64

# %%
# After checking the data types
# Replace "[]" with Empty space
data_movies_6["cast"] = data_movies_6["cast"].replace("[]", "")
utils.validation.replace_nan_with_empty_string(data_movies_6, "cast")
# Out:
#                                    belongs_to_collection    budget
# 0      {'id': 10194, 'name': 'Toy Story Collection', ...  30000000  \
# 1                                                    NaN  65000000
# 2      {'id': 119050, 'name': 'Grumpy Old Men Collect...         0
# 3                                                    NaN  16000000
# 4      {'id': 96871, 'name': 'Father of the Bride Col...         0
# ...                                                  ...       ...
# 45427                                                NaN         0
# 45429                                                NaN         0
# 45430                                                NaN         0
# 45431                                                NaN         0
# 45432                                                NaN         0
#
#                                                   genres      id
# 0      [{'id': 16, 'name': 'Animation'}, {'id': 35, '...     862  \
# 1      [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...    8844
# 2      [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...   15602
# 3      [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...   31357
# 4                         [{'id': 35, 'name': 'Comedy'}]   11862
# ...                                                  ...     ...
# 45427  [{'id': 18, 'name': 'Drama'}, {'id': 28, 'name...   30840
# 45429                      [{'id': 18, 'name': 'Drama'}]  111109
# 45430  [{'id': 28, 'name': 'Action'}, {'id': 18, 'nam...   67758
# 45431                                                 []  227506
# 45432                                                 []  461257
#
#       original_language                                           overview
# 0                    en  Led by Woody, Andy's toys live happily in his ...  \
# 1                    en  When siblings Judy and Peter discover an encha...
# 2                    en  A family wedding reignites the ancient feud be...
# 3                    en  Cheated on, mistreated and stepped on, the wom...
# 4                    en  Just when George Banks has recovered from his ...
# ...                 ...                                                ...
# 45427                en  Yet another version of the classic epic, with ...
# 45429                tl  An artist struggles to finish his work while a...
# 45430                en  When one of her hits goes wrong, a professiona...
# 45431                en  In a small town live two brothers, one a minis...
# 45432                en  50 years after decriminalisation of homosexual...
#
#       popularity                               production_companies
# 0      21.946943     [{'name': 'Pixar Animation Studios', 'id': 3}]  \
# 1      17.015539  [{'name': 'TriStar Pictures', 'id': 559}, {'na...
# 2        11.7129  [{'name': 'Warner Bros.', 'id': 6194}, {'name'...
# 3       3.859495  [{'name': 'Twentieth Century Fox Film Corporat...
# 4       8.387519  [{'name': 'Sandollar Productions', 'id': 5842}...
# ...          ...                                                ...
# 45427   5.683753  [{'name': 'Westdeutscher Rundfunk (WDR)', 'id'...
# 45429   0.178241             [{'name': 'Sine Olivia', 'id': 19653}]
# 45430   0.903007  [{'name': 'American World Pictures', 'id': 6165}]
# 45431   0.003503               [{'name': 'Yermoliev', 'id': 88753}]
# 45432   0.163015                                                 []
#
#                                     production_countries release_date  ...
# 0      [{'iso_3166_1': 'US', 'name': 'United States o...   1995-10-30  ...  \
# 1      [{'iso_3166_1': 'US', 'name': 'United States o...   1995-12-15  ...
# 2      [{'iso_3166_1': 'US', 'name': 'United States o...   1995-12-22  ...
# 3      [{'iso_3166_1': 'US', 'name': 'United States o...   1995-12-22  ...
# 4      [{'iso_3166_1': 'US', 'name': 'United States o...   1995-02-10  ...
# ...                                                  ...          ...  ...
# 45427  [{'iso_3166_1': 'CA', 'name': 'Canada'}, {'iso...   1991-05-13  ...
# 45429      [{'iso_3166_1': 'PH', 'name': 'Philippines'}]   2011-11-17  ...
# 45430  [{'iso_3166_1': 'US', 'name': 'United States o...   2003-08-01  ...
# 45431           [{'iso_3166_1': 'RU', 'name': 'Russia'}]   1917-10-21  ...
# 45432   [{'iso_3166_1': 'GB', 'name': 'United Kingdom'}]   2017-06-09  ...
#
#        vote_count                                               cast
# 0          5415.0  [{'cast_id': 14, 'character': 'Woody (voice)',...  \
# 1          2413.0  [{'cast_id': 1, 'character': 'Alan Parrish', '...
# 2            92.0  [{'cast_id': 2, 'character': 'Max Goldman', 'c...
# 3            34.0  [{'cast_id': 1, 'character': "Savannah 'Vannah...
# 4           173.0  [{'cast_id': 1, 'character': 'George Banks', '...
# ...           ...                                                ...
# 45427        26.0  [{'cast_id': 1, 'character': 'Sir Robert Hode'...
# 45429         3.0  [{'cast_id': 1002, 'character': 'Sister Angela...
# 45430         6.0  [{'cast_id': 6, 'character': 'Emily Shaw', 'cr...
# 45431         0.0  [{'cast_id': 2, 'character': '', 'credit_id': ...
# 45432         0.0
#
#                                                     crew release_year
# 0      [{'credit_id': '52fe4284c3a36847f8024f49', 'de...         1995  \
# 1      [{'credit_id': '52fe44bfc3a36847f80a7cd1', 'de...         1995
# 2      [{'credit_id': '52fe466a9251416c75077a89', 'de...         1995
# 3      [{'credit_id': '52fe44779251416c91011acb', 'de...         1995
# 4      [{'credit_id': '52fe44959251416c75039ed7', 'de...         1995
# ...                                                  ...          ...
# 45427  [{'credit_id': '52fe44439251416c9100a899', 'de...         1991
# 45429  [{'credit_id': '52fe4af1c3a36847f81e9b15', 'de...         2011
# 45430  [{'credit_id': '52fe4776c3a368484e0c8387', 'de...         2003
# 45431  [{'credit_id': '533bccebc3a36844cf0011a7', 'de...         1917
# 45432  [{'credit_id': '593e676c92514105b702e68e', 'de...         2017
#
#           return                                            crew_id
# 0      12.451801  [7879, 12891, 7, 12892, 12893, 12894, 12895, 1...  \
# 1       4.043035  [511, 876, 1729, 4945, 4951, 4952, 8023, 9967,...
# 2       0.000000                     [26502, 16837, 16837, 1551320]
# 3       5.090760  [2178, 5144, 5144, 21968, 70592, 111118, 11111...
# 4       0.000000      [37, 5506, 17698, 17698, 26160, 56106, 68755]
# ...          ...                                                ...
# 45427   0.000000  [17784, 1471628, 39812, 1471628, 18073, 10716,...
# 45429   0.000000  [1051381, 1051381, 1728582, 1051381, 1051381, ...
# 45430   0.000000              [67753, 19713, 549355, 549356, 58818]
# 45431   0.000000                                 [1085341, 1195656]
# 45432   0.000000                                          [1344495]
#
#                                                crew_name
# 0      [John Lasseter, Joss Whedon, Andrew Stanton, J...  \
# 1      [Larry J. Franco, Jonathan Hensleigh, James Ho...
# 2      [Howard Deutch, Mark Steven Johnson, Mark Stev...
# 3      [Forest Whitaker, Ronald Bass, Ronald Bass, Ez...
# 4      [Alan Silvestri, Elliot Davis, Nancy Meyers, N...
# ...                                                  ...
# 45427  [John Irvin, Sam Resnick, John McGrath, Sam Re...
# 45429  [Lav Diaz, Lav Diaz, Dante Perez, Lav Diaz, La...
# 45430  [Mark L. Lester, C. Courtney Joyner, Jeffrey G...
# 45431            [Yakov Protazanov, Joseph N. Ermolieff]
# 45432                                    [Daisy Asquith]
#
#                                              crew_gender
# 0      [2, 2, 2, 2, 0, 1, 0, 2, 2, 2, 2, 2, 0, 0, 0, ...  \
# 1       [2, 2, 2, 2, 2, 0, 0, 2, 2, 2, 2, 2, 2, 2, 2, 2]
# 2                                           [2, 2, 2, 2]
# 3                         [2, 0, 0, 2, 1, 0, 0, 0, 2, 0]
# 4                                  [2, 2, 1, 1, 2, 2, 2]
# ...                                                  ...
# 45427                        [2, 0, 2, 0, 1, 0, 0, 2, 1]
# 45429                                 [0, 0, 0, 0, 0, 0]
# 45430                                    [2, 2, 2, 0, 2]
# 45431                                             [0, 2]
# 45432                                                [0]
#
#                                          crew_department
# 0      [Directing, Writing, Writing, Writing, Writing...  \
# 1      [Production, Writing, Sound, Directing, Editin...
# 2                    [Directing, Writing, Writing, Crew]
# 3      [Directing, Writing, Production, Production, P...
# 4      [Sound, Camera, Writing, Production, Writing, ...
# ...                                                  ...
# 45427  [Directing, Writing, Writing, Writing, Product...
# 45429    [Directing, Writing, Art, Sound, Editing, Crew]
# 45430       [Directing, Writing, Writing, Sound, Camera]
# 45431                            [Directing, Production]
# 45432                                        [Directing]
#
#                                                 crew_job
# 0      [Director, Screenplay, Screenplay, Screenplay,...
# 1      [Executive Producer, Screenplay, Original Musi...
# 2        [Director, Characters, Writer, Sound Recordist]
# 3      [Director, Screenplay, Producer, Producer, Pro...
# 4      [Original Music Composer, Director of Photogra...
# ...                                                  ...
# 45427  [Director, Writer, Writer, Story, Producer, Mu...
# 45429  [Director, Writer, Production Design, Music, E...
# 45430  [Director, Screenplay, Screenplay, Original Mu...
# 45431                               [Director, Producer]
# 45432                                         [Director]
#
# [45346 rows x 27 columns]

# %%
utils.validation.get_column_summary(data_movies_6, "cast")
# Out:
# (cast
#  <class 'str'>    45346
#  Name: count, dtype: int64,
#  'total values:',
#  45346)

# %% [markdown]
# Checking valid python syntax

# %%
# Check valid python syntax for cast column
valid_cast = utils.validation.check_valid_expression(data_movies_6, "cast")
valid_cast
# Out:
# {'valid_count': 42997,
#  'invalid_count': 2349,
#  'nan_count': 0,
#  'blank_count': 2349,
#  'error_count': 0,
#  'invalid_values': [],
#  'error_values': []}

# %% [markdown]
# Extracting values

# %%
# Ectracting nested values from cast
column_name = "cast"
keys = ["id", "name", "gender", "character"]
new_columns = ["actor_id", "actor_name", "actor_gender", "actor_character"]

# %%
utils.validation.extract_values(data_movies_6, column_name, keys, new_columns)
# Out:
#                                    belongs_to_collection    budget
# 0      {'id': 10194, 'name': 'Toy Story Collection', ...  30000000  \
# 1                                                    NaN  65000000
# 2      {'id': 119050, 'name': 'Grumpy Old Men Collect...         0
# 3                                                    NaN  16000000
# 4      {'id': 96871, 'name': 'Father of the Bride Col...         0
# ...                                                  ...       ...
# 45427                                                NaN         0
# 45429                                                NaN         0
# 45430                                                NaN         0
# 45431                                                NaN         0
# 45432                                                NaN         0
#
#                                                   genres      id
# 0      [{'id': 16, 'name': 'Animation'}, {'id': 35, '...     862  \
# 1      [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...    8844
# 2      [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...   15602
# 3      [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...   31357
# 4                         [{'id': 35, 'name': 'Comedy'}]   11862
# ...                                                  ...     ...
# 45427  [{'id': 18, 'name': 'Drama'}, {'id': 28, 'name...   30840
# 45429                      [{'id': 18, 'name': 'Drama'}]  111109
# 45430  [{'id': 28, 'name': 'Action'}, {'id': 18, 'nam...   67758
# 45431                                                 []  227506
# 45432                                                 []  461257
#
#       original_language                                           overview
# 0                    en  Led by Woody, Andy's toys live happily in his ...  \
# 1                    en  When siblings Judy and Peter discover an encha...
# 2                    en  A family wedding reignites the ancient feud be...
# 3                    en  Cheated on, mistreated and stepped on, the wom...
# 4                    en  Just when George Banks has recovered from his ...
# ...                 ...                                                ...
# 45427                en  Yet another version of the classic epic, with ...
# 45429                tl  An artist struggles to finish his work while a...
# 45430                en  When one of her hits goes wrong, a professiona...
# 45431                en  In a small town live two brothers, one a minis...
# 45432                en  50 years after decriminalisation of homosexual...
#
#       popularity                               production_companies
# 0      21.946943     [{'name': 'Pixar Animation Studios', 'id': 3}]  \
# 1      17.015539  [{'name': 'TriStar Pictures', 'id': 559}, {'na...
# 2        11.7129  [{'name': 'Warner Bros.', 'id': 6194}, {'name'...
# 3       3.859495  [{'name': 'Twentieth Century Fox Film Corporat...
# 4       8.387519  [{'name': 'Sandollar Productions', 'id': 5842}...
# ...          ...                                                ...
# 45427   5.683753  [{'name': 'Westdeutscher Rundfunk (WDR)', 'id'...
# 45429   0.178241             [{'name': 'Sine Olivia', 'id': 19653}]
# 45430   0.903007  [{'name': 'American World Pictures', 'id': 6165}]
# 45431   0.003503               [{'name': 'Yermoliev', 'id': 88753}]
# 45432   0.163015                                                 []
#
#                                     production_countries release_date  ...
# 0      [{'iso_3166_1': 'US', 'name': 'United States o...   1995-10-30  ...  \
# 1      [{'iso_3166_1': 'US', 'name': 'United States o...   1995-12-15  ...
# 2      [{'iso_3166_1': 'US', 'name': 'United States o...   1995-12-22  ...
# 3      [{'iso_3166_1': 'US', 'name': 'United States o...   1995-12-22  ...
# 4      [{'iso_3166_1': 'US', 'name': 'United States o...   1995-02-10  ...
# ...                                                  ...          ...  ...
# 45427  [{'iso_3166_1': 'CA', 'name': 'Canada'}, {'iso...   1991-05-13  ...
# 45429      [{'iso_3166_1': 'PH', 'name': 'Philippines'}]   2011-11-17  ...
# 45430  [{'iso_3166_1': 'US', 'name': 'United States o...   2003-08-01  ...
# 45431           [{'iso_3166_1': 'RU', 'name': 'Russia'}]   1917-10-21  ...
# 45432   [{'iso_3166_1': 'GB', 'name': 'United Kingdom'}]   2017-06-09  ...
#
#           return                                            crew_id
# 0      12.451801  [7879, 12891, 7, 12892, 12893, 12894, 12895, 1...  \
# 1       4.043035  [511, 876, 1729, 4945, 4951, 4952, 8023, 9967,...
# 2       0.000000                     [26502, 16837, 16837, 1551320]
# 3       5.090760  [2178, 5144, 5144, 21968, 70592, 111118, 11111...
# 4       0.000000      [37, 5506, 17698, 17698, 26160, 56106, 68755]
# ...          ...                                                ...
# 45427   0.000000  [17784, 1471628, 39812, 1471628, 18073, 10716,...
# 45429   0.000000  [1051381, 1051381, 1728582, 1051381, 1051381, ...
# 45430   0.000000              [67753, 19713, 549355, 549356, 58818]
# 45431   0.000000                                 [1085341, 1195656]
# 45432   0.000000                                          [1344495]
#
#                                                crew_name
# 0      [John Lasseter, Joss Whedon, Andrew Stanton, J...  \
# 1      [Larry J. Franco, Jonathan Hensleigh, James Ho...
# 2      [Howard Deutch, Mark Steven Johnson, Mark Stev...
# 3      [Forest Whitaker, Ronald Bass, Ronald Bass, Ez...
# 4      [Alan Silvestri, Elliot Davis, Nancy Meyers, N...
# ...                                                  ...
# 45427  [John Irvin, Sam Resnick, John McGrath, Sam Re...
# 45429  [Lav Diaz, Lav Diaz, Dante Perez, Lav Diaz, La...
# 45430  [Mark L. Lester, C. Courtney Joyner, Jeffrey G...
# 45431            [Yakov Protazanov, Joseph N. Ermolieff]
# 45432                                    [Daisy Asquith]
#
#                                              crew_gender
# 0      [2, 2, 2, 2, 0, 1, 0, 2, 2, 2, 2, 2, 0, 0, 0, ...  \
# 1       [2, 2, 2, 2, 2, 0, 0, 2, 2, 2, 2, 2, 2, 2, 2, 2]
# 2                                           [2, 2, 2, 2]
# 3                         [2, 0, 0, 2, 1, 0, 0, 0, 2, 0]
# 4                                  [2, 2, 1, 1, 2, 2, 2]
# ...                                                  ...
# 45427                        [2, 0, 2, 0, 1, 0, 0, 2, 1]
# 45429                                 [0, 0, 0, 0, 0, 0]
# 45430                                    [2, 2, 2, 0, 2]
# 45431                                             [0, 2]
# 45432                                                [0]
#
#                                          crew_department
# 0      [Directing, Writing, Writing, Writing, Writing...  \
# 1      [Production, Writing, Sound, Directing, Editin...
# 2                    [Directing, Writing, Writing, Crew]
# 3      [Directing, Writing, Production, Production, P...
# 4      [Sound, Camera, Writing, Production, Writing, ...
# ...                                                  ...
# 45427  [Directing, Writing, Writing, Writing, Product...
# 45429    [Directing, Writing, Art, Sound, Editing, Crew]
# 45430       [Directing, Writing, Writing, Sound, Camera]
# 45431                            [Directing, Production]
# 45432                                        [Directing]
#
#                                                 crew_job
# 0      [Director, Screenplay, Screenplay, Screenplay,...  \
# 1      [Executive Producer, Screenplay, Original Musi...
# 2        [Director, Characters, Writer, Sound Recordist]
# 3      [Director, Screenplay, Producer, Producer, Pro...
# 4      [Original Music Composer, Director of Photogra...
# ...                                                  ...
# 45427  [Director, Writer, Writer, Story, Producer, Mu...
# 45429  [Director, Writer, Production Design, Music, E...
# 45430  [Director, Screenplay, Screenplay, Original Mu...
# 45431                               [Director, Producer]
# 45432                                         [Director]
#
#                                                 actor_id
# 0      [31, 12898, 7167, 12899, 12900, 7907, 8873, 11...  \
# 1      [2157, 8537, 205, 145151, 5149, 10739, 58563, ...
# 2           [6837, 3151, 13567, 16757, 589, 16523, 7166]
# 3      [8851, 9780, 18284, 51359, 66804, 352, 87118, ...
# 4      [67773, 3092, 519, 70696, 59222, 18793, 14592,...
# ...                                                  ...
# 45427                     [29459, 139, 18616, 920, 1924]
# 45429  [1043186, 111636, 1204271, 278923, 1042953, 57...
# 45430  [23764, 2059, 46277, 1736, 58646, 54649, 55270...
# 45431         [544742, 1090923, 1136422, 1261758, 29199]
# 45432         [544742, 1090923, 1136422, 1261758, 29199]
#
#                                               actor_name
# 0      [Tom Hanks, Tim Allen, Don Rickles, Jim Varney...  \
# 1      [Robin Williams, Jonathan Hyde, Kirsten Dunst,...
# 2      [Walter Matthau, Jack Lemmon, Ann-Margret, Sop...
# 3      [Whitney Houston, Angela Bassett, Loretta Devi...
# 4      [Steve Martin, Diane Keaton, Martin Short, Kim...
# ...                                                  ...
# 45427  [Patrick Bergin, Uma Thurman, David Morrissey,...
# 45429  [Angel Aquino, Perry Dizon, Hazel Orencio, Joe...
# 45430  [Erika Eleniak, Adam Baldwin, Julie du Page, J...
# 45431  [Iwan Mosschuchin, Nathalie Lissenko, Pavel Pa...
# 45432  [Iwan Mosschuchin, Nathalie Lissenko, Pavel Pa...
#
#                                             actor_gender
# 0                [2, 2, 2, 2, 2, 2, 1, 0, 2, 1, 2, 1, 2]  \
# 1      [2, 2, 1, 0, 1, 1, 2, 1, 0, 1, 2, 1, 2, 0, 0, ...
# 2                                  [2, 2, 1, 1, 1, 2, 2]
# 3                         [1, 1, 1, 1, 2, 2, 2, 2, 2, 2]
# 4                   [2, 1, 2, 1, 2, 0, 2, 2, 1, 1, 2, 1]
# ...                                                  ...
# 45427                                    [2, 1, 2, 2, 0]
# 45429                  [1, 0, 0, 2, 0, 0, 0, 0, 0, 0, 0]
# 45430      [1, 2, 1, 2, 2, 2, 2, 2, 2, 0, 2, 2, 2, 2, 0]
# 45431                                    [2, 1, 2, 0, 1]
# 45432                                    [2, 1, 2, 0, 1]
#
#                                          actor_character
# 0      [Woody (voice), Buzz Lightyear (voice), Mr. Po...
# 1      [Alan Parrish, Samuel Alan Parrish / Van Pelt,...
# 2      [Max Goldman, John Gustafson, Ariel Gustafson,...
# 3      [Savannah 'Vannah' Jackson, Bernadine 'Bernie'...
# 4      [George Banks, Nina Banks, Franck Eggelhoffer,...
# ...                                                  ...
# 45427  [Sir Robert Hode, Maid Marian, Little John, Si...
# 45429  [Sister Angela, Homer, Crazy Woman/Virgin, Ama...
# 45430  [Emily Shaw, Det. Mark Winston, Jayne Ferré, A...
# 45431                                         [, , , , ]
# 45432                                         [, , , , ]
#
# [45346 rows x 31 columns]

# %% [markdown]
# ##### Working with "spoken languages" values

# %% [markdown]
# Checking valid python syntax

# %%
# Check valid python syntax for spoken_languages column
valid_spoken_languages = utils.validation.check_valid_expression(data_movies_5, "spoken_languages")
valid_spoken_languages
# Out:
# {'valid_count': 45346,
#  'invalid_count': 0,
#  'nan_count': 0,
#  'blank_count': 0,
#  'error_count': 0,
#  'invalid_values': [],
#  'error_values': []}

# %% [markdown]
# Extracting values

# %%
# Ectracting nested values from spoken languages
column_name = "spoken_languages"
keys = ["iso_639_1", "name"]
new_columns = ["initial_sp_languages", "sp_languages"]

# %%
utils.validation.extract_values(data_movies_6, column_name, keys, new_columns)
# Out:
#                                    belongs_to_collection    budget
# 0      {'id': 10194, 'name': 'Toy Story Collection', ...  30000000  \
# 1                                                    NaN  65000000
# 2      {'id': 119050, 'name': 'Grumpy Old Men Collect...         0
# 3                                                    NaN  16000000
# 4      {'id': 96871, 'name': 'Father of the Bride Col...         0
# ...                                                  ...       ...
# 45427                                                NaN         0
# 45429                                                NaN         0
# 45430                                                NaN         0
# 45431                                                NaN         0
# 45432                                                NaN         0
#
#                                                   genres      id
# 0      [{'id': 16, 'name': 'Animation'}, {'id': 35, '...     862  \
# 1      [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...    8844
# 2      [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...   15602
# 3      [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...   31357
# 4                         [{'id': 35, 'name': 'Comedy'}]   11862
# ...                                                  ...     ...
# 45427  [{'id': 18, 'name': 'Drama'}, {'id': 28, 'name...   30840
# 45429                      [{'id': 18, 'name': 'Drama'}]  111109
# 45430  [{'id': 28, 'name': 'Action'}, {'id': 18, 'nam...   67758
# 45431                                                 []  227506
# 45432                                                 []  461257
#
#       original_language                                           overview
# 0                    en  Led by Woody, Andy's toys live happily in his ...  \
# 1                    en  When siblings Judy and Peter discover an encha...
# 2                    en  A family wedding reignites the ancient feud be...
# 3                    en  Cheated on, mistreated and stepped on, the wom...
# 4                    en  Just when George Banks has recovered from his ...
# ...                 ...                                                ...
# 45427                en  Yet another version of the classic epic, with ...
# 45429                tl  An artist struggles to finish his work while a...
# 45430                en  When one of her hits goes wrong, a professiona...
# 45431                en  In a small town live two brothers, one a minis...
# 45432                en  50 years after decriminalisation of homosexual...
#
#       popularity                               production_companies
# 0      21.946943     [{'name': 'Pixar Animation Studios', 'id': 3}]  \
# 1      17.015539  [{'name': 'TriStar Pictures', 'id': 559}, {'na...
# 2        11.7129  [{'name': 'Warner Bros.', 'id': 6194}, {'name'...
# 3       3.859495  [{'name': 'Twentieth Century Fox Film Corporat...
# 4       8.387519  [{'name': 'Sandollar Productions', 'id': 5842}...
# ...          ...                                                ...
# 45427   5.683753  [{'name': 'Westdeutscher Rundfunk (WDR)', 'id'...
# 45429   0.178241             [{'name': 'Sine Olivia', 'id': 19653}]
# 45430   0.903007  [{'name': 'American World Pictures', 'id': 6165}]
# 45431   0.003503               [{'name': 'Yermoliev', 'id': 88753}]
# 45432   0.163015                                                 []
#
#                                     production_countries release_date  ...
# 0      [{'iso_3166_1': 'US', 'name': 'United States o...   1995-10-30  ...  \
# 1      [{'iso_3166_1': 'US', 'name': 'United States o...   1995-12-15  ...
# 2      [{'iso_3166_1': 'US', 'name': 'United States o...   1995-12-22  ...
# 3      [{'iso_3166_1': 'US', 'name': 'United States o...   1995-12-22  ...
# 4      [{'iso_3166_1': 'US', 'name': 'United States o...   1995-02-10  ...
# ...                                                  ...          ...  ...
# 45427  [{'iso_3166_1': 'CA', 'name': 'Canada'}, {'iso...   1991-05-13  ...
# 45429      [{'iso_3166_1': 'PH', 'name': 'Philippines'}]   2011-11-17  ...
# 45430  [{'iso_3166_1': 'US', 'name': 'United States o...   2003-08-01  ...
# 45431           [{'iso_3166_1': 'RU', 'name': 'Russia'}]   1917-10-21  ...
# 45432   [{'iso_3166_1': 'GB', 'name': 'United Kingdom'}]   2017-06-09  ...
#
#                                                crew_name
# 0      [John Lasseter, Joss Whedon, Andrew Stanton, J...  \
# 1      [Larry J. Franco, Jonathan Hensleigh, James Ho...
# 2      [Howard Deutch, Mark Steven Johnson, Mark Stev...
# 3      [Forest Whitaker, Ronald Bass, Ronald Bass, Ez...
# 4      [Alan Silvestri, Elliot Davis, Nancy Meyers, N...
# ...                                                  ...
# 45427  [John Irvin, Sam Resnick, John McGrath, Sam Re...
# 45429  [Lav Diaz, Lav Diaz, Dante Perez, Lav Diaz, La...
# 45430  [Mark L. Lester, C. Courtney Joyner, Jeffrey G...
# 45431            [Yakov Protazanov, Joseph N. Ermolieff]
# 45432                                    [Daisy Asquith]
#
#                                              crew_gender
# 0      [2, 2, 2, 2, 0, 1, 0, 2, 2, 2, 2, 2, 0, 0, 0, ...  \
# 1       [2, 2, 2, 2, 2, 0, 0, 2, 2, 2, 2, 2, 2, 2, 2, 2]
# 2                                           [2, 2, 2, 2]
# 3                         [2, 0, 0, 2, 1, 0, 0, 0, 2, 0]
# 4                                  [2, 2, 1, 1, 2, 2, 2]
# ...                                                  ...
# 45427                        [2, 0, 2, 0, 1, 0, 0, 2, 1]
# 45429                                 [0, 0, 0, 0, 0, 0]
# 45430                                    [2, 2, 2, 0, 2]
# 45431                                             [0, 2]
# 45432                                                [0]
#
#                                          crew_department
# 0      [Directing, Writing, Writing, Writing, Writing...  \
# 1      [Production, Writing, Sound, Directing, Editin...
# 2                    [Directing, Writing, Writing, Crew]
# 3      [Directing, Writing, Production, Production, P...
# 4      [Sound, Camera, Writing, Production, Writing, ...
# ...                                                  ...
# 45427  [Directing, Writing, Writing, Writing, Product...
# 45429    [Directing, Writing, Art, Sound, Editing, Crew]
# 45430       [Directing, Writing, Writing, Sound, Camera]
# 45431                            [Directing, Production]
# 45432                                        [Directing]
#
#                                                 crew_job
# 0      [Director, Screenplay, Screenplay, Screenplay,...  \
# 1      [Executive Producer, Screenplay, Original Musi...
# 2        [Director, Characters, Writer, Sound Recordist]
# 3      [Director, Screenplay, Producer, Producer, Pro...
# 4      [Original Music Composer, Director of Photogra...
# ...                                                  ...
# 45427  [Director, Writer, Writer, Story, Producer, Mu...
# 45429  [Director, Writer, Production Design, Music, E...
# 45430  [Director, Screenplay, Screenplay, Original Mu...
# 45431                               [Director, Producer]
# 45432                                         [Director]
#
#                                                 actor_id
# 0      [31, 12898, 7167, 12899, 12900, 7907, 8873, 11...  \
# 1      [2157, 8537, 205, 145151, 5149, 10739, 58563, ...
# 2           [6837, 3151, 13567, 16757, 589, 16523, 7166]
# 3      [8851, 9780, 18284, 51359, 66804, 352, 87118, ...
# 4      [67773, 3092, 519, 70696, 59222, 18793, 14592,...
# ...                                                  ...
# 45427                     [29459, 139, 18616, 920, 1924]
# 45429  [1043186, 111636, 1204271, 278923, 1042953, 57...
# 45430  [23764, 2059, 46277, 1736, 58646, 54649, 55270...
# 45431         [544742, 1090923, 1136422, 1261758, 29199]
# 45432         [544742, 1090923, 1136422, 1261758, 29199]
#
#                                               actor_name
# 0      [Tom Hanks, Tim Allen, Don Rickles, Jim Varney...  \
# 1      [Robin Williams, Jonathan Hyde, Kirsten Dunst,...
# 2      [Walter Matthau, Jack Lemmon, Ann-Margret, Sop...
# 3      [Whitney Houston, Angela Bassett, Loretta Devi...
# 4      [Steve Martin, Diane Keaton, Martin Short, Kim...
# ...                                                  ...
# 45427  [Patrick Bergin, Uma Thurman, David Morrissey,...
# 45429  [Angel Aquino, Perry Dizon, Hazel Orencio, Joe...
# 45430  [Erika Eleniak, Adam Baldwin, Julie du Page, J...
# 45431  [Iwan Mosschuchin, Nathalie Lissenko, Pavel Pa...
# 45432  [Iwan Mosschuchin, Nathalie Lissenko, Pavel Pa...
#
#                                             actor_gender
# 0                [2, 2, 2, 2, 2, 2, 1, 0, 2, 1, 2, 1, 2]  \
# 1      [2, 2, 1, 0, 1, 1, 2, 1, 0, 1, 2, 1, 2, 0, 0, ...
# 2                                  [2, 2, 1, 1, 1, 2, 2]
# 3                         [1, 1, 1, 1, 2, 2, 2, 2, 2, 2]
# 4                   [2, 1, 2, 1, 2, 0, 2, 2, 1, 1, 2, 1]
# ...                                                  ...
# 45427                                    [2, 1, 2, 2, 0]
# 45429                  [1, 0, 0, 2, 0, 0, 0, 0, 0, 0, 0]
# 45430      [1, 2, 1, 2, 2, 2, 2, 2, 2, 0, 2, 2, 2, 2, 0]
# 45431                                    [2, 1, 2, 0, 1]
# 45432                                    [2, 1, 2, 0, 1]
#
#                                          actor_character initial_sp_languages
# 0      [Woody (voice), Buzz Lightyear (voice), Mr. Po...                 [en]  \
# 1      [Alan Parrish, Samuel Alan Parrish / Van Pelt,...             [en, fr]
# 2      [Max Goldman, John Gustafson, Ariel Gustafson,...                 [en]
# 3      [Savannah 'Vannah' Jackson, Bernadine 'Bernie'...                 [en]
# 4      [George Banks, Nina Banks, Franck Eggelhoffer,...                 [en]
# ...                                                  ...                  ...
# 45427  [Sir Robert Hode, Maid Marian, Little John, Si...                 [en]
# 45429  [Sister Angela, Homer, Crazy Woman/Virgin, Ama...                 [tl]
# 45430  [Emily Shaw, Det. Mark Winston, Jayne Ferré, A...                 [en]
# 45431                                         [, , , , ]                   []
# 45432                                         [, , , , ]                 [en]
#
#               sp_languages
# 0                [English]
# 1      [English, Français]
# 2                [English]
# 3                [English]
# 4                [English]
# ...                    ...
# 45427            [English]
# 45429                   []
# 45430            [English]
# 45431                   []
# 45432            [English]
#
# [45346 rows x 33 columns]

# %% [markdown]
# ##### Working with "production countries" values

# %% [markdown]
# Checking valid python syntax

# %%
# Check valid python syntax for production_counties column
valid_product_countries = utils.validation.check_valid_expression(data_movies_5, "production_countries")
valid_product_countries
# Out:
# {'valid_count': 45346,
#  'invalid_count': 0,
#  'nan_count': 0,
#  'blank_count': 0,
#  'error_count': 0,
#  'invalid_values': [],
#  'error_values': []}

# %% [markdown]
# Extracting values

# %%
# Ectracting nested values from production countries
column_name = "production_countries"
keys = ["iso_3166_1", "name"]
new_columns = ["initial_prod_countries", "prod_countries"]

# %%
utils.validation.extract_values(data_movies_6, column_name, keys, new_columns)
# Out:
#                                    belongs_to_collection    budget
# 0      {'id': 10194, 'name': 'Toy Story Collection', ...  30000000  \
# 1                                                    NaN  65000000
# 2      {'id': 119050, 'name': 'Grumpy Old Men Collect...         0
# 3                                                    NaN  16000000
# 4      {'id': 96871, 'name': 'Father of the Bride Col...         0
# ...                                                  ...       ...
# 45427                                                NaN         0
# 45429                                                NaN         0
# 45430                                                NaN         0
# 45431                                                NaN         0
# 45432                                                NaN         0
#
#                                                   genres      id
# 0      [{'id': 16, 'name': 'Animation'}, {'id': 35, '...     862  \
# 1      [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...    8844
# 2      [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...   15602
# 3      [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...   31357
# 4                         [{'id': 35, 'name': 'Comedy'}]   11862
# ...                                                  ...     ...
# 45427  [{'id': 18, 'name': 'Drama'}, {'id': 28, 'name...   30840
# 45429                      [{'id': 18, 'name': 'Drama'}]  111109
# 45430  [{'id': 28, 'name': 'Action'}, {'id': 18, 'nam...   67758
# 45431                                                 []  227506
# 45432                                                 []  461257
#
#       original_language                                           overview
# 0                    en  Led by Woody, Andy's toys live happily in his ...  \
# 1                    en  When siblings Judy and Peter discover an encha...
# 2                    en  A family wedding reignites the ancient feud be...
# 3                    en  Cheated on, mistreated and stepped on, the wom...
# 4                    en  Just when George Banks has recovered from his ...
# ...                 ...                                                ...
# 45427                en  Yet another version of the classic epic, with ...
# 45429                tl  An artist struggles to finish his work while a...
# 45430                en  When one of her hits goes wrong, a professiona...
# 45431                en  In a small town live two brothers, one a minis...
# 45432                en  50 years after decriminalisation of homosexual...
#
#       popularity                               production_companies
# 0      21.946943     [{'name': 'Pixar Animation Studios', 'id': 3}]  \
# 1      17.015539  [{'name': 'TriStar Pictures', 'id': 559}, {'na...
# 2        11.7129  [{'name': 'Warner Bros.', 'id': 6194}, {'name'...
# 3       3.859495  [{'name': 'Twentieth Century Fox Film Corporat...
# 4       8.387519  [{'name': 'Sandollar Productions', 'id': 5842}...
# ...          ...                                                ...
# 45427   5.683753  [{'name': 'Westdeutscher Rundfunk (WDR)', 'id'...
# 45429   0.178241             [{'name': 'Sine Olivia', 'id': 19653}]
# 45430   0.903007  [{'name': 'American World Pictures', 'id': 6165}]
# 45431   0.003503               [{'name': 'Yermoliev', 'id': 88753}]
# 45432   0.163015                                                 []
#
#                                     production_countries release_date  ...
# 0      [{'iso_3166_1': 'US', 'name': 'United States o...   1995-10-30  ...  \
# 1      [{'iso_3166_1': 'US', 'name': 'United States o...   1995-12-15  ...
# 2      [{'iso_3166_1': 'US', 'name': 'United States o...   1995-12-22  ...
# 3      [{'iso_3166_1': 'US', 'name': 'United States o...   1995-12-22  ...
# 4      [{'iso_3166_1': 'US', 'name': 'United States o...   1995-02-10  ...
# ...                                                  ...          ...  ...
# 45427  [{'iso_3166_1': 'CA', 'name': 'Canada'}, {'iso...   1991-05-13  ...
# 45429      [{'iso_3166_1': 'PH', 'name': 'Philippines'}]   2011-11-17  ...
# 45430  [{'iso_3166_1': 'US', 'name': 'United States o...   2003-08-01  ...
# 45431           [{'iso_3166_1': 'RU', 'name': 'Russia'}]   1917-10-21  ...
# 45432   [{'iso_3166_1': 'GB', 'name': 'United Kingdom'}]   2017-06-09  ...
#
#                                          crew_department
# 0      [Directing, Writing, Writing, Writing, Writing...  \
# 1      [Production, Writing, Sound, Directing, Editin...
# 2                    [Directing, Writing, Writing, Crew]
# 3      [Directing, Writing, Production, Production, P...
# 4      [Sound, Camera, Writing, Production, Writing, ...
# ...                                                  ...
# 45427  [Directing, Writing, Writing, Writing, Product...
# 45429    [Directing, Writing, Art, Sound, Editing, Crew]
# 45430       [Directing, Writing, Writing, Sound, Camera]
# 45431                            [Directing, Production]
# 45432                                        [Directing]
#
#                                                 crew_job
# 0      [Director, Screenplay, Screenplay, Screenplay,...  \
# 1      [Executive Producer, Screenplay, Original Musi...
# 2        [Director, Characters, Writer, Sound Recordist]
# 3      [Director, Screenplay, Producer, Producer, Pro...
# 4      [Original Music Composer, Director of Photogra...
# ...                                                  ...
# 45427  [Director, Writer, Writer, Story, Producer, Mu...
# 45429  [Director, Writer, Production Design, Music, E...
# 45430  [Director, Screenplay, Screenplay, Original Mu...
# 45431                               [Director, Producer]
# 45432                                         [Director]
#
#                                                 actor_id
# 0      [31, 12898, 7167, 12899, 12900, 7907, 8873, 11...  \
# 1      [2157, 8537, 205, 145151, 5149, 10739, 58563, ...
# 2           [6837, 3151, 13567, 16757, 589, 16523, 7166]
# 3      [8851, 9780, 18284, 51359, 66804, 352, 87118, ...
# 4      [67773, 3092, 519, 70696, 59222, 18793, 14592,...
# ...                                                  ...
# 45427                     [29459, 139, 18616, 920, 1924]
# 45429  [1043186, 111636, 1204271, 278923, 1042953, 57...
# 45430  [23764, 2059, 46277, 1736, 58646, 54649, 55270...
# 45431         [544742, 1090923, 1136422, 1261758, 29199]
# 45432         [544742, 1090923, 1136422, 1261758, 29199]
#
#                                               actor_name
# 0      [Tom Hanks, Tim Allen, Don Rickles, Jim Varney...  \
# 1      [Robin Williams, Jonathan Hyde, Kirsten Dunst,...
# 2      [Walter Matthau, Jack Lemmon, Ann-Margret, Sop...
# 3      [Whitney Houston, Angela Bassett, Loretta Devi...
# 4      [Steve Martin, Diane Keaton, Martin Short, Kim...
# ...                                                  ...
# 45427  [Patrick Bergin, Uma Thurman, David Morrissey,...
# 45429  [Angel Aquino, Perry Dizon, Hazel Orencio, Joe...
# 45430  [Erika Eleniak, Adam Baldwin, Julie du Page, J...
# 45431  [Iwan Mosschuchin, Nathalie Lissenko, Pavel Pa...
# 45432  [Iwan Mosschuchin, Nathalie Lissenko, Pavel Pa...
#
#                                             actor_gender
# 0                [2, 2, 2, 2, 2, 2, 1, 0, 2, 1, 2, 1, 2]  \
# 1      [2, 2, 1, 0, 1, 1, 2, 1, 0, 1, 2, 1, 2, 0, 0, ...
# 2                                  [2, 2, 1, 1, 1, 2, 2]
# 3                         [1, 1, 1, 1, 2, 2, 2, 2, 2, 2]
# 4                   [2, 1, 2, 1, 2, 0, 2, 2, 1, 1, 2, 1]
# ...                                                  ...
# 45427                                    [2, 1, 2, 2, 0]
# 45429                  [1, 0, 0, 2, 0, 0, 0, 0, 0, 0, 0]
# 45430      [1, 2, 1, 2, 2, 2, 2, 2, 2, 0, 2, 2, 2, 2, 0]
# 45431                                    [2, 1, 2, 0, 1]
# 45432                                    [2, 1, 2, 0, 1]
#
#                                          actor_character
# 0      [Woody (voice), Buzz Lightyear (voice), Mr. Po...  \
# 1      [Alan Parrish, Samuel Alan Parrish / Van Pelt,...
# 2      [Max Goldman, John Gustafson, Ariel Gustafson,...
# 3      [Savannah 'Vannah' Jackson, Bernadine 'Bernie'...
# 4      [George Banks, Nina Banks, Franck Eggelhoffer,...
# ...                                                  ...
# 45427  [Sir Robert Hode, Maid Marian, Little John, Si...
# 45429  [Sister Angela, Homer, Crazy Woman/Virgin, Ama...
# 45430  [Emily Shaw, Det. Mark Winston, Jayne Ferré, A...
# 45431                                         [, , , , ]
# 45432                                         [, , , , ]
#
#        initial_sp_languages         sp_languages initial_prod_countries
# 0                      [en]            [English]                   [US]  \
# 1                  [en, fr]  [English, Français]                   [US]
# 2                      [en]            [English]                   [US]
# 3                      [en]            [English]                   [US]
# 4                      [en]            [English]                   [US]
# ...                     ...                  ...                    ...
# 45427                  [en]            [English]       [CA, DE, GB, US]
# 45429                  [tl]                   []                   [PH]
# 45430                  [en]            [English]                   [US]
# 45431                    []                   []                   [RU]
# 45432                  [en]            [English]                   [GB]
#
#                                           prod_countries
# 0                             [United States of America]
# 1                             [United States of America]
# 2                             [United States of America]
# 3                             [United States of America]
# 4                             [United States of America]
# ...                                                  ...
# 45427  [Canada, Germany, United Kingdom, United State...
# 45429                                      [Philippines]
# 45430                         [United States of America]
# 45431                                           [Russia]
# 45432                                   [United Kingdom]
#
# [45346 rows x 35 columns]

# %% [markdown]
# ##### Working with "production companies" values

# %% [markdown]
# Checking valid python syntax

# %%
# Check valid python syntax for production_companies column
valid_product_companies = utils.validation.check_valid_expression(data_movies_5, "production_companies")
valid_product_companies
# Out:
# {'valid_count': 45346,
#  'invalid_count': 0,
#  'nan_count': 0,
#  'blank_count': 0,
#  'error_count': 0,
#  'invalid_values': [],
#  'error_values': []}

# %% [markdown]
# Extracting values

# %%
# Ectracting nested values from production companies
column_name = "production_companies"
keys = ["id", "name"]
new_columns = ["companies_id", "companies_name"]

# %%
utils.validation.extract_values(data_movies_6, column_name, keys, new_columns)
# Out:
#                                    belongs_to_collection    budget
# 0      {'id': 10194, 'name': 'Toy Story Collection', ...  30000000  \
# 1                                                    NaN  65000000
# 2      {'id': 119050, 'name': 'Grumpy Old Men Collect...         0
# 3                                                    NaN  16000000
# 4      {'id': 96871, 'name': 'Father of the Bride Col...         0
# ...                                                  ...       ...
# 45427                                                NaN         0
# 45429                                                NaN         0
# 45430                                                NaN         0
# 45431                                                NaN         0
# 45432                                                NaN         0
#
#                                                   genres      id
# 0      [{'id': 16, 'name': 'Animation'}, {'id': 35, '...     862  \
# 1      [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...    8844
# 2      [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...   15602
# 3      [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...   31357
# 4                         [{'id': 35, 'name': 'Comedy'}]   11862
# ...                                                  ...     ...
# 45427  [{'id': 18, 'name': 'Drama'}, {'id': 28, 'name...   30840
# 45429                      [{'id': 18, 'name': 'Drama'}]  111109
# 45430  [{'id': 28, 'name': 'Action'}, {'id': 18, 'nam...   67758
# 45431                                                 []  227506
# 45432                                                 []  461257
#
#       original_language                                           overview
# 0                    en  Led by Woody, Andy's toys live happily in his ...  \
# 1                    en  When siblings Judy and Peter discover an encha...
# 2                    en  A family wedding reignites the ancient feud be...
# 3                    en  Cheated on, mistreated and stepped on, the wom...
# 4                    en  Just when George Banks has recovered from his ...
# ...                 ...                                                ...
# 45427                en  Yet another version of the classic epic, with ...
# 45429                tl  An artist struggles to finish his work while a...
# 45430                en  When one of her hits goes wrong, a professiona...
# 45431                en  In a small town live two brothers, one a minis...
# 45432                en  50 years after decriminalisation of homosexual...
#
#       popularity                               production_companies
# 0      21.946943     [{'name': 'Pixar Animation Studios', 'id': 3}]  \
# 1      17.015539  [{'name': 'TriStar Pictures', 'id': 559}, {'na...
# 2        11.7129  [{'name': 'Warner Bros.', 'id': 6194}, {'name'...
# 3       3.859495  [{'name': 'Twentieth Century Fox Film Corporat...
# 4       8.387519  [{'name': 'Sandollar Productions', 'id': 5842}...
# ...          ...                                                ...
# 45427   5.683753  [{'name': 'Westdeutscher Rundfunk (WDR)', 'id'...
# 45429   0.178241             [{'name': 'Sine Olivia', 'id': 19653}]
# 45430   0.903007  [{'name': 'American World Pictures', 'id': 6165}]
# 45431   0.003503               [{'name': 'Yermoliev', 'id': 88753}]
# 45432   0.163015                                                 []
#
#                                     production_countries release_date  ...
# 0      [{'iso_3166_1': 'US', 'name': 'United States o...   1995-10-30  ...  \
# 1      [{'iso_3166_1': 'US', 'name': 'United States o...   1995-12-15  ...
# 2      [{'iso_3166_1': 'US', 'name': 'United States o...   1995-12-22  ...
# 3      [{'iso_3166_1': 'US', 'name': 'United States o...   1995-12-22  ...
# 4      [{'iso_3166_1': 'US', 'name': 'United States o...   1995-02-10  ...
# ...                                                  ...          ...  ...
# 45427  [{'iso_3166_1': 'CA', 'name': 'Canada'}, {'iso...   1991-05-13  ...
# 45429      [{'iso_3166_1': 'PH', 'name': 'Philippines'}]   2011-11-17  ...
# 45430  [{'iso_3166_1': 'US', 'name': 'United States o...   2003-08-01  ...
# 45431           [{'iso_3166_1': 'RU', 'name': 'Russia'}]   1917-10-21  ...
# 45432   [{'iso_3166_1': 'GB', 'name': 'United Kingdom'}]   2017-06-09  ...
#
#                                                 actor_id
# 0      [31, 12898, 7167, 12899, 12900, 7907, 8873, 11...  \
# 1      [2157, 8537, 205, 145151, 5149, 10739, 58563, ...
# 2           [6837, 3151, 13567, 16757, 589, 16523, 7166]
# 3      [8851, 9780, 18284, 51359, 66804, 352, 87118, ...
# 4      [67773, 3092, 519, 70696, 59222, 18793, 14592,...
# ...                                                  ...
# 45427                     [29459, 139, 18616, 920, 1924]
# 45429  [1043186, 111636, 1204271, 278923, 1042953, 57...
# 45430  [23764, 2059, 46277, 1736, 58646, 54649, 55270...
# 45431         [544742, 1090923, 1136422, 1261758, 29199]
# 45432         [544742, 1090923, 1136422, 1261758, 29199]
#
#                                               actor_name
# 0      [Tom Hanks, Tim Allen, Don Rickles, Jim Varney...  \
# 1      [Robin Williams, Jonathan Hyde, Kirsten Dunst,...
# 2      [Walter Matthau, Jack Lemmon, Ann-Margret, Sop...
# 3      [Whitney Houston, Angela Bassett, Loretta Devi...
# 4      [Steve Martin, Diane Keaton, Martin Short, Kim...
# ...                                                  ...
# 45427  [Patrick Bergin, Uma Thurman, David Morrissey,...
# 45429  [Angel Aquino, Perry Dizon, Hazel Orencio, Joe...
# 45430  [Erika Eleniak, Adam Baldwin, Julie du Page, J...
# 45431  [Iwan Mosschuchin, Nathalie Lissenko, Pavel Pa...
# 45432  [Iwan Mosschuchin, Nathalie Lissenko, Pavel Pa...
#
#                                             actor_gender
# 0                [2, 2, 2, 2, 2, 2, 1, 0, 2, 1, 2, 1, 2]  \
# 1      [2, 2, 1, 0, 1, 1, 2, 1, 0, 1, 2, 1, 2, 0, 0, ...
# 2                                  [2, 2, 1, 1, 1, 2, 2]
# 3                         [1, 1, 1, 1, 2, 2, 2, 2, 2, 2]
# 4                   [2, 1, 2, 1, 2, 0, 2, 2, 1, 1, 2, 1]
# ...                                                  ...
# 45427                                    [2, 1, 2, 2, 0]
# 45429                  [1, 0, 0, 2, 0, 0, 0, 0, 0, 0, 0]
# 45430      [1, 2, 1, 2, 2, 2, 2, 2, 2, 0, 2, 2, 2, 2, 0]
# 45431                                    [2, 1, 2, 0, 1]
# 45432                                    [2, 1, 2, 0, 1]
#
#                                          actor_character initial_sp_languages
# 0      [Woody (voice), Buzz Lightyear (voice), Mr. Po...                 [en]  \
# 1      [Alan Parrish, Samuel Alan Parrish / Van Pelt,...             [en, fr]
# 2      [Max Goldman, John Gustafson, Ariel Gustafson,...                 [en]
# 3      [Savannah 'Vannah' Jackson, Bernadine 'Bernie'...                 [en]
# 4      [George Banks, Nina Banks, Franck Eggelhoffer,...                 [en]
# ...                                                  ...                  ...
# 45427  [Sir Robert Hode, Maid Marian, Little John, Si...                 [en]
# 45429  [Sister Angela, Homer, Crazy Woman/Virgin, Ama...                 [tl]
# 45430  [Emily Shaw, Det. Mark Winston, Jayne Ferré, A...                 [en]
# 45431                                         [, , , , ]                   []
# 45432                                         [, , , , ]                 [en]
#
#               sp_languages  initial_prod_countries
# 0                [English]                    [US]  \
# 1      [English, Français]                    [US]
# 2                [English]                    [US]
# 3                [English]                    [US]
# 4                [English]                    [US]
# ...                    ...                     ...
# 45427            [English]        [CA, DE, GB, US]
# 45429                   []                    [PH]
# 45430            [English]                    [US]
# 45431                   []                    [RU]
# 45432            [English]                    [GB]
#
#                                           prod_countries
# 0                             [United States of America]  \
# 1                             [United States of America]
# 2                             [United States of America]
# 3                             [United States of America]
# 4                             [United States of America]
# ...                                                  ...
# 45427  [Canada, Germany, United Kingdom, United State...
# 45429                                      [Philippines]
# 45430                         [United States of America]
# 45431                                           [Russia]
# 45432                                   [United Kingdom]
#
#                       companies_id
# 0                              [3]  \
# 1               [559, 2550, 10201]
# 2                    [6194, 19464]
# 3                            [306]
# 4                     [5842, 9195]
# ...                            ...
# 45427  [7025, 10163, 16323, 38978]
# 45429                      [19653]
# 45430                       [6165]
# 45431                      [88753]
# 45432                           []
#
#                                           companies_name
# 0                              [Pixar Animation Studios]
# 1      [TriStar Pictures, Teitler Film, Interscope Co...
# 2                         [Warner Bros., Lancaster Gate]
# 3               [Twentieth Century Fox Film Corporation]
# 4           [Sandollar Productions, Touchstone Pictures]
# ...                                                  ...
# 45427  [Westdeutscher Rundfunk (WDR), Working Title F...
# 45429                                      [Sine Olivia]
# 45430                          [American World Pictures]
# 45431                                        [Yermoliev]
# 45432                                                 []
#
# [45346 rows x 37 columns]

# %% [markdown]
# ##### Working with "genres" values

# %% [markdown]
# Checking valid python syntax

# %%
# Check valid python syntax for genres column
valid_genres = utils.validation.check_valid_expression(data_movies_5, "genres")
valid_genres
# Out:
# {'valid_count': 45346,
#  'invalid_count': 0,
#  'nan_count': 0,
#  'blank_count': 0,
#  'error_count': 0,
#  'invalid_values': [],
#  'error_values': []}

# %% [markdown]
# Extracting values

# %%
# Ectracting nested values from genres
column_name = "genres"
keys = ["id", "name"]
new_columns = ["movie_genres_id", "movie_genres"]

# %%
utils.validation.extract_values(data_movies_6, column_name, keys, new_columns)
# Out:
#                                    belongs_to_collection    budget
# 0      {'id': 10194, 'name': 'Toy Story Collection', ...  30000000  \
# 1                                                    NaN  65000000
# 2      {'id': 119050, 'name': 'Grumpy Old Men Collect...         0
# 3                                                    NaN  16000000
# 4      {'id': 96871, 'name': 'Father of the Bride Col...         0
# ...                                                  ...       ...
# 45427                                                NaN         0
# 45429                                                NaN         0
# 45430                                                NaN         0
# 45431                                                NaN         0
# 45432                                                NaN         0
#
#                                                   genres      id
# 0      [{'id': 16, 'name': 'Animation'}, {'id': 35, '...     862  \
# 1      [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...    8844
# 2      [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...   15602
# 3      [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...   31357
# 4                         [{'id': 35, 'name': 'Comedy'}]   11862
# ...                                                  ...     ...
# 45427  [{'id': 18, 'name': 'Drama'}, {'id': 28, 'name...   30840
# 45429                      [{'id': 18, 'name': 'Drama'}]  111109
# 45430  [{'id': 28, 'name': 'Action'}, {'id': 18, 'nam...   67758
# 45431                                                 []  227506
# 45432                                                 []  461257
#
#       original_language                                           overview
# 0                    en  Led by Woody, Andy's toys live happily in his ...  \
# 1                    en  When siblings Judy and Peter discover an encha...
# 2                    en  A family wedding reignites the ancient feud be...
# 3                    en  Cheated on, mistreated and stepped on, the wom...
# 4                    en  Just when George Banks has recovered from his ...
# ...                 ...                                                ...
# 45427                en  Yet another version of the classic epic, with ...
# 45429                tl  An artist struggles to finish his work while a...
# 45430                en  When one of her hits goes wrong, a professiona...
# 45431                en  In a small town live two brothers, one a minis...
# 45432                en  50 years after decriminalisation of homosexual...
#
#       popularity                               production_companies
# 0      21.946943     [{'name': 'Pixar Animation Studios', 'id': 3}]  \
# 1      17.015539  [{'name': 'TriStar Pictures', 'id': 559}, {'na...
# 2        11.7129  [{'name': 'Warner Bros.', 'id': 6194}, {'name'...
# 3       3.859495  [{'name': 'Twentieth Century Fox Film Corporat...
# 4       8.387519  [{'name': 'Sandollar Productions', 'id': 5842}...
# ...          ...                                                ...
# 45427   5.683753  [{'name': 'Westdeutscher Rundfunk (WDR)', 'id'...
# 45429   0.178241             [{'name': 'Sine Olivia', 'id': 19653}]
# 45430   0.903007  [{'name': 'American World Pictures', 'id': 6165}]
# 45431   0.003503               [{'name': 'Yermoliev', 'id': 88753}]
# 45432   0.163015                                                 []
#
#                                     production_countries release_date  ...
# 0      [{'iso_3166_1': 'US', 'name': 'United States o...   1995-10-30  ...  \
# 1      [{'iso_3166_1': 'US', 'name': 'United States o...   1995-12-15  ...
# 2      [{'iso_3166_1': 'US', 'name': 'United States o...   1995-12-22  ...
# 3      [{'iso_3166_1': 'US', 'name': 'United States o...   1995-12-22  ...
# 4      [{'iso_3166_1': 'US', 'name': 'United States o...   1995-02-10  ...
# ...                                                  ...          ...  ...
# 45427  [{'iso_3166_1': 'CA', 'name': 'Canada'}, {'iso...   1991-05-13  ...
# 45429      [{'iso_3166_1': 'PH', 'name': 'Philippines'}]   2011-11-17  ...
# 45430  [{'iso_3166_1': 'US', 'name': 'United States o...   2003-08-01  ...
# 45431           [{'iso_3166_1': 'RU', 'name': 'Russia'}]   1917-10-21  ...
# 45432   [{'iso_3166_1': 'GB', 'name': 'United Kingdom'}]   2017-06-09  ...
#
#                                             actor_gender
# 0                [2, 2, 2, 2, 2, 2, 1, 0, 2, 1, 2, 1, 2]  \
# 1      [2, 2, 1, 0, 1, 1, 2, 1, 0, 1, 2, 1, 2, 0, 0, ...
# 2                                  [2, 2, 1, 1, 1, 2, 2]
# 3                         [1, 1, 1, 1, 2, 2, 2, 2, 2, 2]
# 4                   [2, 1, 2, 1, 2, 0, 2, 2, 1, 1, 2, 1]
# ...                                                  ...
# 45427                                    [2, 1, 2, 2, 0]
# 45429                  [1, 0, 0, 2, 0, 0, 0, 0, 0, 0, 0]
# 45430      [1, 2, 1, 2, 2, 2, 2, 2, 2, 0, 2, 2, 2, 2, 0]
# 45431                                    [2, 1, 2, 0, 1]
# 45432                                    [2, 1, 2, 0, 1]
#
#                                          actor_character initial_sp_languages
# 0      [Woody (voice), Buzz Lightyear (voice), Mr. Po...                 [en]  \
# 1      [Alan Parrish, Samuel Alan Parrish / Van Pelt,...             [en, fr]
# 2      [Max Goldman, John Gustafson, Ariel Gustafson,...                 [en]
# 3      [Savannah 'Vannah' Jackson, Bernadine 'Bernie'...                 [en]
# 4      [George Banks, Nina Banks, Franck Eggelhoffer,...                 [en]
# ...                                                  ...                  ...
# 45427  [Sir Robert Hode, Maid Marian, Little John, Si...                 [en]
# 45429  [Sister Angela, Homer, Crazy Woman/Virgin, Ama...                 [tl]
# 45430  [Emily Shaw, Det. Mark Winston, Jayne Ferré, A...                 [en]
# 45431                                         [, , , , ]                   []
# 45432                                         [, , , , ]                 [en]
#
#               sp_languages initial_prod_countries
# 0                [English]                   [US]  \
# 1      [English, Français]                   [US]
# 2                [English]                   [US]
# 3                [English]                   [US]
# 4                [English]                   [US]
# ...                    ...                    ...
# 45427            [English]       [CA, DE, GB, US]
# 45429                   []                   [PH]
# 45430            [English]                   [US]
# 45431                   []                   [RU]
# 45432            [English]                   [GB]
#
#                                           prod_countries
# 0                             [United States of America]  \
# 1                             [United States of America]
# 2                             [United States of America]
# 3                             [United States of America]
# 4                             [United States of America]
# ...                                                  ...
# 45427  [Canada, Germany, United Kingdom, United State...
# 45429                                      [Philippines]
# 45430                         [United States of America]
# 45431                                           [Russia]
# 45432                                   [United Kingdom]
#
#                       companies_id
# 0                              [3]  \
# 1               [559, 2550, 10201]
# 2                    [6194, 19464]
# 3                            [306]
# 4                     [5842, 9195]
# ...                            ...
# 45427  [7025, 10163, 16323, 38978]
# 45429                      [19653]
# 45430                       [6165]
# 45431                      [88753]
# 45432                           []
#
#                                           companies_name  movie_genres_id
# 0                              [Pixar Animation Studios]  [16, 35, 10751]  \
# 1      [TriStar Pictures, Teitler Film, Interscope Co...  [12, 14, 10751]
# 2                         [Warner Bros., Lancaster Gate]      [10749, 35]
# 3               [Twentieth Century Fox Film Corporation]  [35, 18, 10749]
# 4           [Sandollar Productions, Touchstone Pictures]             [35]
# ...                                                  ...              ...
# 45427  [Westdeutscher Rundfunk (WDR), Working Title F...  [18, 28, 10749]
# 45429                                      [Sine Olivia]             [18]
# 45430                          [American World Pictures]     [28, 18, 53]
# 45431                                        [Yermoliev]               []
# 45432                                                 []               []
#
#                        movie_genres
# 0       [Animation, Comedy, Family]
# 1      [Adventure, Fantasy, Family]
# 2                 [Romance, Comedy]
# 3          [Comedy, Drama, Romance]
# 4                          [Comedy]
# ...                             ...
# 45427      [Drama, Action, Romance]
# 45429                       [Drama]
# 45430     [Action, Drama, Thriller]
# 45431                            []
# 45432                            []
#
# [45346 rows x 39 columns]

# %% [markdown]
# ##### Working with "belongs to collection" values

# %% [markdown]
# Checking valid python syntax

# %%
# Check valid python syntax for belongs_to_collection column
valid_collection = utils.validation.check_valid_expression(data_movies_5, "belongs_to_collection")
valid_collection
# Out:
# {'valid_count': 4485,
#  'invalid_count': 40861,
#  'nan_count': 40861,
#  'blank_count': 0,
#  'error_count': 0,
#  'invalid_values': [],
#  'error_values': []}

# %% [markdown]
# Extracting values

# %%
# Ectracting nested values from belongs to collection
column_name = "belongs_to_collection"
keys = ["id", "name"]
new_columns = ["collection_id", "collection_name"]

# %%
utils.validation.extract_dict_values(data_movies_6, column_name, keys, new_columns)
# Out:
#                                    belongs_to_collection    budget
# 0      {'id': 10194, 'name': 'Toy Story Collection', ...  30000000  \
# 1                                                    NaN  65000000
# 2      {'id': 119050, 'name': 'Grumpy Old Men Collect...         0
# 3                                                    NaN  16000000
# 4      {'id': 96871, 'name': 'Father of the Bride Col...         0
# ...                                                  ...       ...
# 45427                                                NaN         0
# 45429                                                NaN         0
# 45430                                                NaN         0
# 45431                                                NaN         0
# 45432                                                NaN         0
#
#                                                   genres      id
# 0      [{'id': 16, 'name': 'Animation'}, {'id': 35, '...     862  \
# 1      [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...    8844
# 2      [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...   15602
# 3      [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...   31357
# 4                         [{'id': 35, 'name': 'Comedy'}]   11862
# ...                                                  ...     ...
# 45427  [{'id': 18, 'name': 'Drama'}, {'id': 28, 'name...   30840
# 45429                      [{'id': 18, 'name': 'Drama'}]  111109
# 45430  [{'id': 28, 'name': 'Action'}, {'id': 18, 'nam...   67758
# 45431                                                 []  227506
# 45432                                                 []  461257
#
#       original_language                                           overview
# 0                    en  Led by Woody, Andy's toys live happily in his ...  \
# 1                    en  When siblings Judy and Peter discover an encha...
# 2                    en  A family wedding reignites the ancient feud be...
# 3                    en  Cheated on, mistreated and stepped on, the wom...
# 4                    en  Just when George Banks has recovered from his ...
# ...                 ...                                                ...
# 45427                en  Yet another version of the classic epic, with ...
# 45429                tl  An artist struggles to finish his work while a...
# 45430                en  When one of her hits goes wrong, a professiona...
# 45431                en  In a small town live two brothers, one a minis...
# 45432                en  50 years after decriminalisation of homosexual...
#
#       popularity                               production_companies
# 0      21.946943     [{'name': 'Pixar Animation Studios', 'id': 3}]  \
# 1      17.015539  [{'name': 'TriStar Pictures', 'id': 559}, {'na...
# 2        11.7129  [{'name': 'Warner Bros.', 'id': 6194}, {'name'...
# 3       3.859495  [{'name': 'Twentieth Century Fox Film Corporat...
# 4       8.387519  [{'name': 'Sandollar Productions', 'id': 5842}...
# ...          ...                                                ...
# 45427   5.683753  [{'name': 'Westdeutscher Rundfunk (WDR)', 'id'...
# 45429   0.178241             [{'name': 'Sine Olivia', 'id': 19653}]
# 45430   0.903007  [{'name': 'American World Pictures', 'id': 6165}]
# 45431   0.003503               [{'name': 'Yermoliev', 'id': 88753}]
# 45432   0.163015                                                 []
#
#                                     production_countries release_date  ...
# 0      [{'iso_3166_1': 'US', 'name': 'United States o...   1995-10-30  ...  \
# 1      [{'iso_3166_1': 'US', 'name': 'United States o...   1995-12-15  ...
# 2      [{'iso_3166_1': 'US', 'name': 'United States o...   1995-12-22  ...
# 3      [{'iso_3166_1': 'US', 'name': 'United States o...   1995-12-22  ...
# 4      [{'iso_3166_1': 'US', 'name': 'United States o...   1995-02-10  ...
# ...                                                  ...          ...  ...
# 45427  [{'iso_3166_1': 'CA', 'name': 'Canada'}, {'iso...   1991-05-13  ...
# 45429      [{'iso_3166_1': 'PH', 'name': 'Philippines'}]   2011-11-17  ...
# 45430  [{'iso_3166_1': 'US', 'name': 'United States o...   2003-08-01  ...
# 45431           [{'iso_3166_1': 'RU', 'name': 'Russia'}]   1917-10-21  ...
# 45432   [{'iso_3166_1': 'GB', 'name': 'United Kingdom'}]   2017-06-09  ...
#
#        initial_sp_languages         sp_languages initial_prod_countries
# 0                      [en]            [English]                   [US]  \
# 1                  [en, fr]  [English, Français]                   [US]
# 2                      [en]            [English]                   [US]
# 3                      [en]            [English]                   [US]
# 4                      [en]            [English]                   [US]
# ...                     ...                  ...                    ...
# 45427                  [en]            [English]       [CA, DE, GB, US]
# 45429                  [tl]                   []                   [PH]
# 45430                  [en]            [English]                   [US]
# 45431                    []                   []                   [RU]
# 45432                  [en]            [English]                   [GB]
#
#                                           prod_countries
# 0                             [United States of America]  \
# 1                             [United States of America]
# 2                             [United States of America]
# 3                             [United States of America]
# 4                             [United States of America]
# ...                                                  ...
# 45427  [Canada, Germany, United Kingdom, United State...
# 45429                                      [Philippines]
# 45430                         [United States of America]
# 45431                                           [Russia]
# 45432                                   [United Kingdom]
#
#                       companies_id
# 0                              [3]  \
# 1               [559, 2550, 10201]
# 2                    [6194, 19464]
# 3                            [306]
# 4                     [5842, 9195]
# ...                            ...
# 45427  [7025, 10163, 16323, 38978]
# 45429                      [19653]
# 45430                       [6165]
# 45431                      [88753]
# 45432                           []
#
#                                           companies_name  movie_genres_id
# 0                              [Pixar Animation Studios]  [16, 35, 10751]  \
# 1      [TriStar Pictures, Teitler Film, Interscope Co...  [12, 14, 10751]
# 2                         [Warner Bros., Lancaster Gate]      [10749, 35]
# 3               [Twentieth Century Fox Film Corporation]  [35, 18, 10749]
# 4           [Sandollar Productions, Touchstone Pictures]             [35]
# ...                                                  ...              ...
# 45427  [Westdeutscher Rundfunk (WDR), Working Title F...  [18, 28, 10749]
# 45429                                      [Sine Olivia]             [18]
# 45430                          [American World Pictures]     [28, 18, 53]
# 45431                                        [Yermoliev]               []
# 45432                                                 []               []
#
#                        movie_genres collection_id
# 0       [Animation, Comedy, Family]       [10194]  \
# 1      [Adventure, Fantasy, Family]          None
# 2                 [Romance, Comedy]      [119050]
# 3          [Comedy, Drama, Romance]          None
# 4                          [Comedy]       [96871]
# ...                             ...           ...
# 45427      [Drama, Action, Romance]          None
# 45429                       [Drama]          None
# 45430     [Action, Drama, Thriller]          None
# 45431                            []          None
# 45432                            []          None
#
#                         collection_name
# 0                [Toy Story Collection]
# 1                                  None
# 2           [Grumpy Old Men Collection]
# 3                                  None
# 4      [Father of the Bride Collection]
# ...                                 ...
# 45427                              None
# 45429                              None
# 45430                              None
# 45431                              None
# 45432                              None
#
# [45346 rows x 41 columns]

# %% [markdown]
# #### Check the rest of the columns

# %% [markdown]
# ##### "original languages" column

# %%
utils.validation.get_column_summary(data_movies_6,"original_language")
# Out:
# (original_language
#  <class 'str'>      45335
#  <class 'float'>       11
#  Name: count, dtype: int64,
#  'total values:',
#  45346)

# %%
data_movies_7 = data_movies_6.copy()
dataset = data_movies_7
column = "original_language"

# %%
utils.validation.replace_nan_with_empty_string(dataset, column)
# Out:
#                                    belongs_to_collection    budget
# 0      {'id': 10194, 'name': 'Toy Story Collection', ...  30000000  \
# 1                                                    NaN  65000000
# 2      {'id': 119050, 'name': 'Grumpy Old Men Collect...         0
# 3                                                    NaN  16000000
# 4      {'id': 96871, 'name': 'Father of the Bride Col...         0
# ...                                                  ...       ...
# 45427                                                NaN         0
# 45429                                                NaN         0
# 45430                                                NaN         0
# 45431                                                NaN         0
# 45432                                                NaN         0
#
#                                                   genres      id
# 0      [{'id': 16, 'name': 'Animation'}, {'id': 35, '...     862  \
# 1      [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...    8844
# 2      [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...   15602
# 3      [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...   31357
# 4                         [{'id': 35, 'name': 'Comedy'}]   11862
# ...                                                  ...     ...
# 45427  [{'id': 18, 'name': 'Drama'}, {'id': 28, 'name...   30840
# 45429                      [{'id': 18, 'name': 'Drama'}]  111109
# 45430  [{'id': 28, 'name': 'Action'}, {'id': 18, 'nam...   67758
# 45431                                                 []  227506
# 45432                                                 []  461257
#
#       original_language                                           overview
# 0                    en  Led by Woody, Andy's toys live happily in his ...  \
# 1                    en  When siblings Judy and Peter discover an encha...
# 2                    en  A family wedding reignites the ancient feud be...
# 3                    en  Cheated on, mistreated and stepped on, the wom...
# 4                    en  Just when George Banks has recovered from his ...
# ...                 ...                                                ...
# 45427                en  Yet another version of the classic epic, with ...
# 45429                tl  An artist struggles to finish his work while a...
# 45430                en  When one of her hits goes wrong, a professiona...
# 45431                en  In a small town live two brothers, one a minis...
# 45432                en  50 years after decriminalisation of homosexual...
#
#       popularity                               production_companies
# 0      21.946943     [{'name': 'Pixar Animation Studios', 'id': 3}]  \
# 1      17.015539  [{'name': 'TriStar Pictures', 'id': 559}, {'na...
# 2        11.7129  [{'name': 'Warner Bros.', 'id': 6194}, {'name'...
# 3       3.859495  [{'name': 'Twentieth Century Fox Film Corporat...
# 4       8.387519  [{'name': 'Sandollar Productions', 'id': 5842}...
# ...          ...                                                ...
# 45427   5.683753  [{'name': 'Westdeutscher Rundfunk (WDR)', 'id'...
# 45429   0.178241             [{'name': 'Sine Olivia', 'id': 19653}]
# 45430   0.903007  [{'name': 'American World Pictures', 'id': 6165}]
# 45431   0.003503               [{'name': 'Yermoliev', 'id': 88753}]
# 45432   0.163015                                                 []
#
#                                     production_countries release_date  ...
# 0      [{'iso_3166_1': 'US', 'name': 'United States o...   1995-10-30  ...  \
# 1      [{'iso_3166_1': 'US', 'name': 'United States o...   1995-12-15  ...
# 2      [{'iso_3166_1': 'US', 'name': 'United States o...   1995-12-22  ...
# 3      [{'iso_3166_1': 'US', 'name': 'United States o...   1995-12-22  ...
# 4      [{'iso_3166_1': 'US', 'name': 'United States o...   1995-02-10  ...
# ...                                                  ...          ...  ...
# 45427  [{'iso_3166_1': 'CA', 'name': 'Canada'}, {'iso...   1991-05-13  ...
# 45429      [{'iso_3166_1': 'PH', 'name': 'Philippines'}]   2011-11-17  ...
# 45430  [{'iso_3166_1': 'US', 'name': 'United States o...   2003-08-01  ...
# 45431           [{'iso_3166_1': 'RU', 'name': 'Russia'}]   1917-10-21  ...
# 45432   [{'iso_3166_1': 'GB', 'name': 'United Kingdom'}]   2017-06-09  ...
#
#        initial_sp_languages         sp_languages initial_prod_countries
# 0                      [en]            [English]                   [US]  \
# 1                  [en, fr]  [English, Français]                   [US]
# 2                      [en]            [English]                   [US]
# 3                      [en]            [English]                   [US]
# 4                      [en]            [English]                   [US]
# ...                     ...                  ...                    ...
# 45427                  [en]            [English]       [CA, DE, GB, US]
# 45429                  [tl]                   []                   [PH]
# 45430                  [en]            [English]                   [US]
# 45431                    []                   []                   [RU]
# 45432                  [en]            [English]                   [GB]
#
#                                           prod_countries
# 0                             [United States of America]  \
# 1                             [United States of America]
# 2                             [United States of America]
# 3                             [United States of America]
# 4                             [United States of America]
# ...                                                  ...
# 45427  [Canada, Germany, United Kingdom, United State...
# 45429                                      [Philippines]
# 45430                         [United States of America]
# 45431                                           [Russia]
# 45432                                   [United Kingdom]
#
#                       companies_id
# 0                              [3]  \
# 1               [559, 2550, 10201]
# 2                    [6194, 19464]
# 3                            [306]
# 4                     [5842, 9195]
# ...                            ...
# 45427  [7025, 10163, 16323, 38978]
# 45429                      [19653]
# 45430                       [6165]
# 45431                      [88753]
# 45432                           []
#
#                                           companies_name  movie_genres_id
# 0                              [Pixar Animation Studios]  [16, 35, 10751]  \
# 1      [TriStar Pictures, Teitler Film, Interscope Co...  [12, 14, 10751]
# 2                         [Warner Bros., Lancaster Gate]      [10749, 35]
# 3               [Twentieth Century Fox Film Corporation]  [35, 18, 10749]
# 4           [Sandollar Productions, Touchstone Pictures]             [35]
# ...                                                  ...              ...
# 45427  [Westdeutscher Rundfunk (WDR), Working Title F...  [18, 28, 10749]
# 45429                                      [Sine Olivia]             [18]
# 45430                          [American World Pictures]     [28, 18, 53]
# 45431                                        [Yermoliev]               []
# 45432                                                 []               []
#
#                        movie_genres collection_id
# 0       [Animation, Comedy, Family]       [10194]  \
# 1      [Adventure, Fantasy, Family]          None
# 2                 [Romance, Comedy]      [119050]
# 3          [Comedy, Drama, Romance]          None
# 4                          [Comedy]       [96871]
# ...                             ...           ...
# 45427      [Drama, Action, Romance]          None
# 45429                       [Drama]          None
# 45430     [Action, Drama, Thriller]          None
# 45431                            []          None
# 45432                            []          None
#
#                         collection_name
# 0                [Toy Story Collection]
# 1                                  None
# 2           [Grumpy Old Men Collection]
# 3                                  None
# 4      [Father of the Bride Collection]
# ...                                 ...
# 45427                              None
# 45429                              None
# 45430                              None
# 45431                              None
# 45432                              None
#
# [45346 rows x 41 columns]

# %%
utils.validation.get_column_summary(data_movies_7,"original_language")
# Out:
# (original_language
#  <class 'str'>    45346
#  Name: count, dtype: int64,
#  'total values:',
#  45346)

# %% [markdown]
# ##### "overview" column

# %%
utils.validation.get_column_summary(data_movies_7,"overview")
# Out:
# (overview
#  <class 'str'>      44405
#  <class 'float'>      941
#  Name: count, dtype: int64,
#  'total values:',
#  45346)

# %%
dataset = data_movies_7
column = "overview"
utils.validation.replace_nan_with_empty_string(dataset, column)
# Out:
#                                    belongs_to_collection    budget
# 0      {'id': 10194, 'name': 'Toy Story Collection', ...  30000000  \
# 1                                                    NaN  65000000
# 2      {'id': 119050, 'name': 'Grumpy Old Men Collect...         0
# 3                                                    NaN  16000000
# 4      {'id': 96871, 'name': 'Father of the Bride Col...         0
# ...                                                  ...       ...
# 45427                                                NaN         0
# 45429                                                NaN         0
# 45430                                                NaN         0
# 45431                                                NaN         0
# 45432                                                NaN         0
#
#                                                   genres      id
# 0      [{'id': 16, 'name': 'Animation'}, {'id': 35, '...     862  \
# 1      [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...    8844
# 2      [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...   15602
# 3      [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...   31357
# 4                         [{'id': 35, 'name': 'Comedy'}]   11862
# ...                                                  ...     ...
# 45427  [{'id': 18, 'name': 'Drama'}, {'id': 28, 'name...   30840
# 45429                      [{'id': 18, 'name': 'Drama'}]  111109
# 45430  [{'id': 28, 'name': 'Action'}, {'id': 18, 'nam...   67758
# 45431                                                 []  227506
# 45432                                                 []  461257
#
#       original_language                                           overview
# 0                    en  Led by Woody, Andy's toys live happily in his ...  \
# 1                    en  When siblings Judy and Peter discover an encha...
# 2                    en  A family wedding reignites the ancient feud be...
# 3                    en  Cheated on, mistreated and stepped on, the wom...
# 4                    en  Just when George Banks has recovered from his ...
# ...                 ...                                                ...
# 45427                en  Yet another version of the classic epic, with ...
# 45429                tl  An artist struggles to finish his work while a...
# 45430                en  When one of her hits goes wrong, a professiona...
# 45431                en  In a small town live two brothers, one a minis...
# 45432                en  50 years after decriminalisation of homosexual...
#
#       popularity                               production_companies
# 0      21.946943     [{'name': 'Pixar Animation Studios', 'id': 3}]  \
# 1      17.015539  [{'name': 'TriStar Pictures', 'id': 559}, {'na...
# 2        11.7129  [{'name': 'Warner Bros.', 'id': 6194}, {'name'...
# 3       3.859495  [{'name': 'Twentieth Century Fox Film Corporat...
# 4       8.387519  [{'name': 'Sandollar Productions', 'id': 5842}...
# ...          ...                                                ...
# 45427   5.683753  [{'name': 'Westdeutscher Rundfunk (WDR)', 'id'...
# 45429   0.178241             [{'name': 'Sine Olivia', 'id': 19653}]
# 45430   0.903007  [{'name': 'American World Pictures', 'id': 6165}]
# 45431   0.003503               [{'name': 'Yermoliev', 'id': 88753}]
# 45432   0.163015                                                 []
#
#                                     production_countries release_date  ...
# 0      [{'iso_3166_1': 'US', 'name': 'United States o...   1995-10-30  ...  \
# 1      [{'iso_3166_1': 'US', 'name': 'United States o...   1995-12-15  ...
# 2      [{'iso_3166_1': 'US', 'name': 'United States o...   1995-12-22  ...
# 3      [{'iso_3166_1': 'US', 'name': 'United States o...   1995-12-22  ...
# 4      [{'iso_3166_1': 'US', 'name': 'United States o...   1995-02-10  ...
# ...                                                  ...          ...  ...
# 45427  [{'iso_3166_1': 'CA', 'name': 'Canada'}, {'iso...   1991-05-13  ...
# 45429      [{'iso_3166_1': 'PH', 'name': 'Philippines'}]   2011-11-17  ...
# 45430  [{'iso_3166_1': 'US', 'name': 'United States o...   2003-08-01  ...
# 45431           [{'iso_3166_1': 'RU', 'name': 'Russia'}]   1917-10-21  ...
# 45432   [{'iso_3166_1': 'GB', 'name': 'United Kingdom'}]   2017-06-09  ...
#
#        initial_sp_languages         sp_languages initial_prod_countries
# 0                      [en]            [English]                   [US]  \
# 1                  [en, fr]  [English, Français]                   [US]
# 2                      [en]            [English]                   [US]
# 3                      [en]            [English]                   [US]
# 4                      [en]            [English]                   [US]
# ...                     ...                  ...                    ...
# 45427                  [en]            [English]       [CA, DE, GB, US]
# 45429                  [tl]                   []                   [PH]
# 45430                  [en]            [English]                   [US]
# 45431                    []                   []                   [RU]
# 45432                  [en]            [English]                   [GB]
#
#                                           prod_countries
# 0                             [United States of America]  \
# 1                             [United States of America]
# 2                             [United States of America]
# 3                             [United States of America]
# 4                             [United States of America]
# ...                                                  ...
# 45427  [Canada, Germany, United Kingdom, United State...
# 45429                                      [Philippines]
# 45430                         [United States of America]
# 45431                                           [Russia]
# 45432                                   [United Kingdom]
#
#                       companies_id
# 0                              [3]  \
# 1               [559, 2550, 10201]
# 2                    [6194, 19464]
# 3                            [306]
# 4                     [5842, 9195]
# ...                            ...
# 45427  [7025, 10163, 16323, 38978]
# 45429                      [19653]
# 45430                       [6165]
# 45431                      [88753]
# 45432                           []
#
#                                           companies_name  movie_genres_id
# 0                              [Pixar Animation Studios]  [16, 35, 10751]  \
# 1      [TriStar Pictures, Teitler Film, Interscope Co...  [12, 14, 10751]
# 2                         [Warner Bros., Lancaster Gate]      [10749, 35]
# 3               [Twentieth Century Fox Film Corporation]  [35, 18, 10749]
# 4           [Sandollar Productions, Touchstone Pictures]             [35]
# ...                                                  ...              ...
# 45427  [Westdeutscher Rundfunk (WDR), Working Title F...  [18, 28, 10749]
# 45429                                      [Sine Olivia]             [18]
# 45430                          [American World Pictures]     [28, 18, 53]
# 45431                                        [Yermoliev]               []
# 45432                                                 []               []
#
#                        movie_genres collection_id
# 0       [Animation, Comedy, Family]       [10194]  \
# 1      [Adventure, Fantasy, Family]          None
# 2                 [Romance, Comedy]      [119050]
# 3          [Comedy, Drama, Romance]          None
# 4                          [Comedy]       [96871]
# ...                             ...           ...
# 45427      [Drama, Action, Romance]          None
# 45429                       [Drama]          None
# 45430     [Action, Drama, Thriller]          None
# 45431                            []          None
# 45432                            []          None
#
#                         collection_name
# 0                [Toy Story Collection]
# 1                                  None
# 2           [Grumpy Old Men Collection]
# 3                                  None
# 4      [Father of the Bride Collection]
# ...                                 ...
# 45427                              None
# 45429                              None
# 45430                              None
# 45431                              None
# 45432                              None
#
# [45346 rows x 41 columns]

# %%
utils.validation.get_column_summary(data_movies_7,"overview")
# Out:
# (overview
#  <class 'str'>    45346
#  Name: count, dtype: int64,
#  'total values:',
#  45346)

# %% [markdown]
# ##### "runtime" column

# %%
utils.validation.get_column_summary(data_movies_7,"runtime")
# Out:
# (runtime
#  <class 'float'>    45346
#  Name: count, dtype: int64,
#  'total values:',
#  45346)

# %% [markdown]
# ##### "status" column

# %%
utils.validation.get_column_summary(data_movies_7,"status")
# Out:
# (status
#  <class 'str'>      45266
#  <class 'float'>       80
#  Name: count, dtype: int64,
#  'total values:',
#  45346)

# %%
dataset = data_movies_7
column = "status"
utils.validation.replace_nan_with_empty_string(dataset, column)
# Out:
#                                    belongs_to_collection    budget
# 0      {'id': 10194, 'name': 'Toy Story Collection', ...  30000000  \
# 1                                                    NaN  65000000
# 2      {'id': 119050, 'name': 'Grumpy Old Men Collect...         0
# 3                                                    NaN  16000000
# 4      {'id': 96871, 'name': 'Father of the Bride Col...         0
# ...                                                  ...       ...
# 45427                                                NaN         0
# 45429                                                NaN         0
# 45430                                                NaN         0
# 45431                                                NaN         0
# 45432                                                NaN         0
#
#                                                   genres      id
# 0      [{'id': 16, 'name': 'Animation'}, {'id': 35, '...     862  \
# 1      [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...    8844
# 2      [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...   15602
# 3      [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...   31357
# 4                         [{'id': 35, 'name': 'Comedy'}]   11862
# ...                                                  ...     ...
# 45427  [{'id': 18, 'name': 'Drama'}, {'id': 28, 'name...   30840
# 45429                      [{'id': 18, 'name': 'Drama'}]  111109
# 45430  [{'id': 28, 'name': 'Action'}, {'id': 18, 'nam...   67758
# 45431                                                 []  227506
# 45432                                                 []  461257
#
#       original_language                                           overview
# 0                    en  Led by Woody, Andy's toys live happily in his ...  \
# 1                    en  When siblings Judy and Peter discover an encha...
# 2                    en  A family wedding reignites the ancient feud be...
# 3                    en  Cheated on, mistreated and stepped on, the wom...
# 4                    en  Just when George Banks has recovered from his ...
# ...                 ...                                                ...
# 45427                en  Yet another version of the classic epic, with ...
# 45429                tl  An artist struggles to finish his work while a...
# 45430                en  When one of her hits goes wrong, a professiona...
# 45431                en  In a small town live two brothers, one a minis...
# 45432                en  50 years after decriminalisation of homosexual...
#
#       popularity                               production_companies
# 0      21.946943     [{'name': 'Pixar Animation Studios', 'id': 3}]  \
# 1      17.015539  [{'name': 'TriStar Pictures', 'id': 559}, {'na...
# 2        11.7129  [{'name': 'Warner Bros.', 'id': 6194}, {'name'...
# 3       3.859495  [{'name': 'Twentieth Century Fox Film Corporat...
# 4       8.387519  [{'name': 'Sandollar Productions', 'id': 5842}...
# ...          ...                                                ...
# 45427   5.683753  [{'name': 'Westdeutscher Rundfunk (WDR)', 'id'...
# 45429   0.178241             [{'name': 'Sine Olivia', 'id': 19653}]
# 45430   0.903007  [{'name': 'American World Pictures', 'id': 6165}]
# 45431   0.003503               [{'name': 'Yermoliev', 'id': 88753}]
# 45432   0.163015                                                 []
#
#                                     production_countries release_date  ...
# 0      [{'iso_3166_1': 'US', 'name': 'United States o...   1995-10-30  ...  \
# 1      [{'iso_3166_1': 'US', 'name': 'United States o...   1995-12-15  ...
# 2      [{'iso_3166_1': 'US', 'name': 'United States o...   1995-12-22  ...
# 3      [{'iso_3166_1': 'US', 'name': 'United States o...   1995-12-22  ...
# 4      [{'iso_3166_1': 'US', 'name': 'United States o...   1995-02-10  ...
# ...                                                  ...          ...  ...
# 45427  [{'iso_3166_1': 'CA', 'name': 'Canada'}, {'iso...   1991-05-13  ...
# 45429      [{'iso_3166_1': 'PH', 'name': 'Philippines'}]   2011-11-17  ...
# 45430  [{'iso_3166_1': 'US', 'name': 'United States o...   2003-08-01  ...
# 45431           [{'iso_3166_1': 'RU', 'name': 'Russia'}]   1917-10-21  ...
# 45432   [{'iso_3166_1': 'GB', 'name': 'United Kingdom'}]   2017-06-09  ...
#
#        initial_sp_languages         sp_languages initial_prod_countries
# 0                      [en]            [English]                   [US]  \
# 1                  [en, fr]  [English, Français]                   [US]
# 2                      [en]            [English]                   [US]
# 3                      [en]            [English]                   [US]
# 4                      [en]            [English]                   [US]
# ...                     ...                  ...                    ...
# 45427                  [en]            [English]       [CA, DE, GB, US]
# 45429                  [tl]                   []                   [PH]
# 45430                  [en]            [English]                   [US]
# 45431                    []                   []                   [RU]
# 45432                  [en]            [English]                   [GB]
#
#                                           prod_countries
# 0                             [United States of America]  \
# 1                             [United States of America]
# 2                             [United States of America]
# 3                             [United States of America]
# 4                             [United States of America]
# ...                                                  ...
# 45427  [Canada, Germany, United Kingdom, United State...
# 45429                                      [Philippines]
# 45430                         [United States of America]
# 45431                                           [Russia]
# 45432                                   [United Kingdom]
#
#                       companies_id
# 0                              [3]  \
# 1               [559, 2550, 10201]
# 2                    [6194, 19464]
# 3                            [306]
# 4                     [5842, 9195]
# ...                            ...
# 45427  [7025, 10163, 16323, 38978]
# 45429                      [19653]
# 45430                       [6165]
# 45431                      [88753]
# 45432                           []
#
#                                           companies_name  movie_genres_id
# 0                              [Pixar Animation Studios]  [16, 35, 10751]  \
# 1      [TriStar Pictures, Teitler Film, Interscope Co...  [12, 14, 10751]
# 2                         [Warner Bros., Lancaster Gate]      [10749, 35]
# 3               [Twentieth Century Fox Film Corporation]  [35, 18, 10749]
# 4           [Sandollar Productions, Touchstone Pictures]             [35]
# ...                                                  ...              ...
# 45427  [Westdeutscher Rundfunk (WDR), Working Title F...  [18, 28, 10749]
# 45429                                      [Sine Olivia]             [18]
# 45430                          [American World Pictures]     [28, 18, 53]
# 45431                                        [Yermoliev]               []
# 45432                                                 []               []
#
#                        movie_genres collection_id
# 0       [Animation, Comedy, Family]       [10194]  \
# 1      [Adventure, Fantasy, Family]          None
# 2                 [Romance, Comedy]      [119050]
# 3          [Comedy, Drama, Romance]          None
# 4                          [Comedy]       [96871]
# ...                             ...           ...
# 45427      [Drama, Action, Romance]          None
# 45429                       [Drama]          None
# 45430     [Action, Drama, Thriller]          None
# 45431                            []          None
# 45432                            []          None
#
#                         collection_name
# 0                [Toy Story Collection]
# 1                                  None
# 2           [Grumpy Old Men Collection]
# 3                                  None
# 4      [Father of the Bride Collection]
# ...                                 ...
# 45427                              None
# 45429                              None
# 45430                              None
# 45431                              None
# 45432                              None
#
# [45346 rows x 41 columns]

# %%
utils.validation.get_column_summary(data_movies_7,"status")
# Out:
# (status
#  <class 'str'>    45346
#  Name: count, dtype: int64,
#  'total values:',
#  45346)

# %% [markdown]
# ##### "tagline" column

# %%
utils.validation.get_column_summary(data_movies_7,"tagline")
# Out:
# (tagline
#  <class 'float'>    24959
#  <class 'str'>      20387
#  Name: count, dtype: int64,
#  'total values:',
#  45346)

# %%
dataset = data_movies_7
column = "tagline"
utils.validation.replace_nan_with_empty_string(dataset, column)
# Out:
#                                    belongs_to_collection    budget
# 0      {'id': 10194, 'name': 'Toy Story Collection', ...  30000000  \
# 1                                                    NaN  65000000
# 2      {'id': 119050, 'name': 'Grumpy Old Men Collect...         0
# 3                                                    NaN  16000000
# 4      {'id': 96871, 'name': 'Father of the Bride Col...         0
# ...                                                  ...       ...
# 45427                                                NaN         0
# 45429                                                NaN         0
# 45430                                                NaN         0
# 45431                                                NaN         0
# 45432                                                NaN         0
#
#                                                   genres      id
# 0      [{'id': 16, 'name': 'Animation'}, {'id': 35, '...     862  \
# 1      [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...    8844
# 2      [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...   15602
# 3      [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...   31357
# 4                         [{'id': 35, 'name': 'Comedy'}]   11862
# ...                                                  ...     ...
# 45427  [{'id': 18, 'name': 'Drama'}, {'id': 28, 'name...   30840
# 45429                      [{'id': 18, 'name': 'Drama'}]  111109
# 45430  [{'id': 28, 'name': 'Action'}, {'id': 18, 'nam...   67758
# 45431                                                 []  227506
# 45432                                                 []  461257
#
#       original_language                                           overview
# 0                    en  Led by Woody, Andy's toys live happily in his ...  \
# 1                    en  When siblings Judy and Peter discover an encha...
# 2                    en  A family wedding reignites the ancient feud be...
# 3                    en  Cheated on, mistreated and stepped on, the wom...
# 4                    en  Just when George Banks has recovered from his ...
# ...                 ...                                                ...
# 45427                en  Yet another version of the classic epic, with ...
# 45429                tl  An artist struggles to finish his work while a...
# 45430                en  When one of her hits goes wrong, a professiona...
# 45431                en  In a small town live two brothers, one a minis...
# 45432                en  50 years after decriminalisation of homosexual...
#
#       popularity                               production_companies
# 0      21.946943     [{'name': 'Pixar Animation Studios', 'id': 3}]  \
# 1      17.015539  [{'name': 'TriStar Pictures', 'id': 559}, {'na...
# 2        11.7129  [{'name': 'Warner Bros.', 'id': 6194}, {'name'...
# 3       3.859495  [{'name': 'Twentieth Century Fox Film Corporat...
# 4       8.387519  [{'name': 'Sandollar Productions', 'id': 5842}...
# ...          ...                                                ...
# 45427   5.683753  [{'name': 'Westdeutscher Rundfunk (WDR)', 'id'...
# 45429   0.178241             [{'name': 'Sine Olivia', 'id': 19653}]
# 45430   0.903007  [{'name': 'American World Pictures', 'id': 6165}]
# 45431   0.003503               [{'name': 'Yermoliev', 'id': 88753}]
# 45432   0.163015                                                 []
#
#                                     production_countries release_date  ...
# 0      [{'iso_3166_1': 'US', 'name': 'United States o...   1995-10-30  ...  \
# 1      [{'iso_3166_1': 'US', 'name': 'United States o...   1995-12-15  ...
# 2      [{'iso_3166_1': 'US', 'name': 'United States o...   1995-12-22  ...
# 3      [{'iso_3166_1': 'US', 'name': 'United States o...   1995-12-22  ...
# 4      [{'iso_3166_1': 'US', 'name': 'United States o...   1995-02-10  ...
# ...                                                  ...          ...  ...
# 45427  [{'iso_3166_1': 'CA', 'name': 'Canada'}, {'iso...   1991-05-13  ...
# 45429      [{'iso_3166_1': 'PH', 'name': 'Philippines'}]   2011-11-17  ...
# 45430  [{'iso_3166_1': 'US', 'name': 'United States o...   2003-08-01  ...
# 45431           [{'iso_3166_1': 'RU', 'name': 'Russia'}]   1917-10-21  ...
# 45432   [{'iso_3166_1': 'GB', 'name': 'United Kingdom'}]   2017-06-09  ...
#
#        initial_sp_languages         sp_languages initial_prod_countries
# 0                      [en]            [English]                   [US]  \
# 1                  [en, fr]  [English, Français]                   [US]
# 2                      [en]            [English]                   [US]
# 3                      [en]            [English]                   [US]
# 4                      [en]            [English]                   [US]
# ...                     ...                  ...                    ...
# 45427                  [en]            [English]       [CA, DE, GB, US]
# 45429                  [tl]                   []                   [PH]
# 45430                  [en]            [English]                   [US]
# 45431                    []                   []                   [RU]
# 45432                  [en]            [English]                   [GB]
#
#                                           prod_countries
# 0                             [United States of America]  \
# 1                             [United States of America]
# 2                             [United States of America]
# 3                             [United States of America]
# 4                             [United States of America]
# ...                                                  ...
# 45427  [Canada, Germany, United Kingdom, United State...
# 45429                                      [Philippines]
# 45430                         [United States of America]
# 45431                                           [Russia]
# 45432                                   [United Kingdom]
#
#                       companies_id
# 0                              [3]  \
# 1               [559, 2550, 10201]
# 2                    [6194, 19464]
# 3                            [306]
# 4                     [5842, 9195]
# ...                            ...
# 45427  [7025, 10163, 16323, 38978]
# 45429                      [19653]
# 45430                       [6165]
# 45431                      [88753]
# 45432                           []
#
#                                           companies_name  movie_genres_id
# 0                              [Pixar Animation Studios]  [16, 35, 10751]  \
# 1      [TriStar Pictures, Teitler Film, Interscope Co...  [12, 14, 10751]
# 2                         [Warner Bros., Lancaster Gate]      [10749, 35]
# 3               [Twentieth Century Fox Film Corporation]  [35, 18, 10749]
# 4           [Sandollar Productions, Touchstone Pictures]             [35]
# ...                                                  ...              ...
# 45427  [Westdeutscher Rundfunk (WDR), Working Title F...  [18, 28, 10749]
# 45429                                      [Sine Olivia]             [18]
# 45430                          [American World Pictures]     [28, 18, 53]
# 45431                                        [Yermoliev]               []
# 45432                                                 []               []
#
#                        movie_genres collection_id
# 0       [Animation, Comedy, Family]       [10194]  \
# 1      [Adventure, Fantasy, Family]          None
# 2                 [Romance, Comedy]      [119050]
# 3          [Comedy, Drama, Romance]          None
# 4                          [Comedy]       [96871]
# ...                             ...           ...
# 45427      [Drama, Action, Romance]          None
# 45429                       [Drama]          None
# 45430     [Action, Drama, Thriller]          None
# 45431                            []          None
# 45432                            []          None
#
#                         collection_name
# 0                [Toy Story Collection]
# 1                                  None
# 2           [Grumpy Old Men Collection]
# 3                                  None
# 4      [Father of the Bride Collection]
# ...                                 ...
# 45427                              None
# 45429                              None
# 45430                              None
# 45431                              None
# 45432                              None
#
# [45346 rows x 41 columns]

# %%
utils.validation.get_column_summary(data_movies_7,"tagline")
# Out:
# (tagline
#  <class 'str'>    45346
#  Name: count, dtype: int64,
#  'total values:',
#  45346)

# %% [markdown]
# ##### "title" column

# %%
utils.validation.get_column_summary(data_movies_7,"title")
# Out:
# (title
#  <class 'str'>    45346
#  Name: count, dtype: int64,
#  'total values:',
#  45346)

# %% [markdown]
# ##### "vote average" column

# %%
utils.validation.get_column_summary(data_movies_7,"vote_average")
# Out:
# (vote_average
#  <class 'float'>    45346
#  Name: count, dtype: int64,
#  'total values:',
#  45346)

# %% [markdown]
# ##### "vote count" columm

# %%
utils.validation.get_column_summary(data_movies_7,"vote_count")
# Out:
# (vote_count
#  <class 'float'>    45346
#  Name: count, dtype: int64,
#  'total values:',
#  45346)

# %% [markdown]
# #### Extract necesary columns for API

# %%
data_movies_7.columns
# Out:
# Index(['belongs_to_collection', 'budget', 'genres', 'id', 'original_language',
#        'overview', 'popularity', 'production_companies',
#        'production_countries', 'release_date', 'revenue', 'runtime',
#        'spoken_languages', 'status', 'tagline', 'title', 'vote_average',
#        'vote_count', 'cast', 'crew', 'release_year', 'return', 'crew_id',
#        'crew_name', 'crew_gender', 'crew_department', 'crew_job', 'actor_id',
#        'actor_name', 'actor_gender', 'actor_character', 'initial_sp_languages',
#        'sp_languages', 'initial_prod_countries', 'prod_countries',
#        'companies_id', 'companies_name', 'movie_genres_id', 'movie_genres',
#        'collection_id', 'collection_name'],
#       dtype='object')

# %%
# Necessary data
# id, title, release date, release year, return , revenue, budget, vote count, vote average, popularity
# actor name, crew name, crew job, status

necessary_columns = ["id", "title", "release_date", "release_year", "status", "return", "revenue", "budget", "vote_count", "vote_average", "popularity", "actor_name", "crew_name", "crew_job"]

# Create a new DataFrame with only the selected columns
api_dataframe = data_movies_7[necessary_columns]

# Save the selected DataFrame to a CSV file
api_dataframe.to_csv('../api/data/api_movies_data.csv', index=False)
